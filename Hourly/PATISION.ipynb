# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Air-pollution-COVID-19-impact/blob/main/Hourly/PATISION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyparsing.helpers import PrecededBy
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Hourly/HPAT.csv'
df = pd.read_csv(url)
print(df)
# Out:
#      HOUR      NOMEAN       NO2O    NO2MEAN      NO22O     O3MEAN       O320
# 0    1:00   58.366412   8.681818  83.000000  39.704545  11.623932  37.956522
# 1    2:00   50.416667   6.340909  75.955056  32.659091  13.277311  41.108696
# 2    3:00   46.962121   6.227273  69.724719  29.954545  15.537815  40.521739
# 3    4:00   42.098485   9.727273  64.382022  27.250000  17.327731  39.891304
# 4    5:00   44.250000  12.181818  62.191011  34.000000  18.058824  32.500000
# 5    6:00   60.878788  25.454545  65.820225  44.181818  14.638655  24.152174
# 6    7:00   95.830769  47.136364  74.482955  53.204545  10.694915  18.500000
# 7    8:00  134.219697  63.409091  82.649718  60.272727   9.644068  14.804348
# 8    9:00  134.893130  58.295455  89.610169  64.227273   8.813559  19.326087
# 9   10:00  110.969697  45.090909  92.432584  66.136364   9.823529  25.869565
# 10  11:00   86.442748  32.909091  91.242938  63.000000  11.840336  32.369565
# 11  12:00   70.207692  25.119048  89.084746  59.214286  14.296610  35.822222
# 12  13:00   59.101562  20.651163  86.264368  57.627907  15.512821  37.456522
# 13  14:00   51.861538  17.930233  85.602273  57.046512  16.222222  40.347826
# 14  15:00   49.116279  16.181818  86.611429  55.772727  17.598291  43.195652
# 15  16:00   46.590909  14.659091  84.825843  53.863636  19.179487  45.304348
# 16  17:00   47.796992  13.250000  85.027933  50.931818  18.177966  48.043478
# 17  18:00   48.804511  11.840909  85.463687  47.500000  17.516949  48.652174
# 18  19:00   52.518797  10.500000  86.932961  46.227273  15.888889  48.413043
# 19  20:00   61.210526  11.136364  90.681564  49.977273  14.101695  43.347826
# 20  21:00   72.751880  13.113636  93.787710  53.022727  11.559322  37.673913
# 21  22:00   77.360902  13.431818  94.212290  52.090909  10.084746  36.282609
# 22  23:00   72.924812  15.409091  91.592179  52.363636   9.703390  32.608696
# 23   0:00   65.172932  11.772727  87.396648  45.568182  10.627119  35.717391

# %%
plt.figure(figsize=(6,3))

plt.xlabel('Hour')
plt.ylabel('$NO_{x}$  $[μg/m^{3}]$')

NO=[]
x=[]
for i in df['NO2O']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    NO+=[i]

NO2=[]
y=[]
for i in df['NO22O']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    NO2+=[i]


O3MEAN=[]
xx=[]
for i in df['O320']:
  if i==0:
    xx+=[None]
  else:
    xx+=[i]
    O3MEAN+=[i]

plt.plot(df['HOUR'], xx, 'red')
plt.scatter(df['HOUR'], xx, color='red' ,label='$O_{3}$ Lockdown 2020')
plt.legend()

plt.plot(df['HOUR'], x, 'green')
plt.scatter(df['HOUR'], x, color='green', label='$NO$ Lockdown 2020')

plt.plot(df['HOUR'], y, 'orange')
plt.scatter(df['HOUR'], y,color='orange', label='$NO_{2}$ Lockdown 2020')

plt.legend()

plt.xlim(df.loc[0]['HOUR'] , df.loc[23]['HOUR'])
plt.ylim(0,100)

plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize=(6,3))

plt.xlabel('Hour')
plt.ylabel('$NO_{x}$  $[μg/m^{3}]$')

NO=[]
x=[]
for i in df['NOMEAN']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    NO+=[i]

NO2=[]
y=[]
for i in df['NO2MEAN']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    NO2+=[i]


O3MEAN=[]
xx=[]
for i in df['O3MEAN']:
  if i==0:
    xx+=[None]
  else:
    xx+=[i]
    O3MEAN+=[i]

plt.plot(df['HOUR'], xx, 'red')
plt.scatter(df['HOUR'], xx, color='red' ,label='$O_{3}$ 2016-19 ')
plt.legend()

plt.plot(df['HOUR'], x, 'green')
plt.scatter(df['HOUR'], x, color='green', label='$NO$ 2016-19')

plt.plot(df['HOUR'], y, 'orange')
plt.scatter(df['HOUR'], y,color='orange', label='$NO_{2}$ 2016-19 ')

plt.legend()

plt.xlim(df.loc[0]['HOUR'] , df.loc[23]['HOUR'])
plt.ylim(0,150)

plt.xticks(rotation=90)

plt.show()
