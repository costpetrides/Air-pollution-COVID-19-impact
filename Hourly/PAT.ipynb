# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Air-pollution-COVID-19-impact/blob/main/Hourly/PAT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyparsing.helpers import PrecededBy
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Hourly/HPAT.csv'
df = pd.read_csv(url)
print(df)
# Out:
#      Hour        NO19       NO2O      NO219      NO22O      CO19      CO2O  \
# 0    1:00   55.285714   7.400000  74.500000  40.666667  1.156667  0.240000
# 1    2:00   44.793103   5.966667  64.586207  33.333333  1.023333  0.210000
# 2    3:00   41.275862   6.600000  59.137931  32.466667  0.886667  0.203333
# 3    4:00   36.413793  10.400000  52.448276  28.266667  0.713333  0.173333
# 4    5:00   38.482759  10.933333  51.689655  34.866667  0.636667  0.216667
# 5    6:00   56.517241  26.333333  58.206897  47.033333  0.666667  0.283333
# 6    7:00   79.821429  53.766667  67.285714  57.466667  1.006667  0.563333
# 7    8:00  109.275862  71.233333  76.655172  65.766667  1.448276  0.823333
# 8    9:00  102.758621  62.866667  82.379310  69.666667  1.633333  0.683333
# 9   10:00   81.241379  48.600000  80.862069  70.733333  1.580000  0.530000
# 10  11:00   59.178571  34.400000  77.535714  66.300000  1.326667  0.410000
# ...

# %%
plt.figure(figsize=(6,3))

plt.xlabel('Hour')
plt.ylabel('$NO_{x}$  $[μg/m^{3}]$')

NO=[]
x=[]
for i in df['NO19']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    NO+=[i]

NO2=[]
xx=[]
for i in df['NO219']:
  if i==0:
    xx+=[None]
  else:
    xx+=[i]
    NO2+=[i]

O3=[]
y=[]
for i in df['O319']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    O3+=[i]

plt.plot(df['Hour'], x, 'green')
plt.scatter(df['Hour'], x, color='green', label='$NO$ 2019')

plt.plot(df['Hour'], xx, 'orange')
plt.scatter(df['Hour'], xx,color='orange', label='$NO_{2}$ 2019')

plt.plot(df['Hour'], y, 'red')
plt.scatter(df['Hour'], y,color='red', label='$O_{3}$ 2019')
plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.ylim(0,120)
plt.legend()
plt.grid(linestyle='--', alpha=0.5)

plt.xticks(rotation=90)
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(10))
plt.grid(linestyle='--', alpha=0.5)
plt.grid(which='minor', axis='y', linestyle='--', linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(6,3))

plt.xlabel('Hour')
plt.ylabel('$NO_{x}$  $[μg/m^{3}]$')

NO=[]
x=[]
for i in df['NO2O']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    NO+=[i]

NO2=[]
xx=[]
for i in df['NO22O']:
  if i==0:
    xx+=[None]
  else:
    xx+=[i]
    NO2+=[i]

O3=[]
y=[]
for i in df['O32O']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    O3+=[i]

plt.plot(df['Hour'], x, 'green')
plt.scatter(df['Hour'], x, color='green', label='$NO$ 2020')

plt.plot(df['Hour'], xx, 'orange')
plt.scatter(df['Hour'], xx,color='orange', label='$NO_{2}$ 2020')

plt.plot(df['Hour'], y, 'red')
plt.scatter(df['Hour'], y,color='red', label='$O_{3}$ 2020')

plt.legend()

plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.grid(linestyle='--', alpha=0.5)
plt.xticks(rotation=90)
plt.ylim(0,120)
plt.legend()

plt.xticks(rotation=90)
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(10))
plt.grid(linestyle='--', alpha=0.5)
plt.grid(which='minor', axis='y', linestyle='--', linewidth=0.5)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(6, 3))


CO=[]
x=[]
for i in df['CO2O']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    CO+=[i]


O3=[]
y=[]
for i in df['O32O']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    O3+=[i]



ax.plot(df['Hour'], x, 'purple')
ax.scatter(df['Hour'], x,color='purple', label='$CO$ 2020')
plt.xticks(rotation=90)

ax2=ax.twinx()
ax2.plot(df['Hour'], y, 'red')
ax2.scatter(df['Hour'], y,color='red', label='$O_{3}$ 2020')

plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.ylim(0,100)
plt.xticks(rotation=90)

ax.set_xlabel('Hours')
ax.set_ylabel(r"CO  $[mg/m^{3}$]")
ax2.set_ylabel(r"$O_{3} \: [μg/m^{3}$]")
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)



ax.set_yticks(np.arange(0, 3.4, 0.4))
ax2.set_yticks(np.arange(0, 160, 20))
ax.set_ylim(0, 2.8)
ax2.set_ylim(0, 140)
ax.grid(linestyle='--', alpha=0.5)

plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(10))
plt.grid(linestyle='--', alpha=0.5)
plt.grid(which='minor', axis='y', linestyle='--', linewidth=0.5)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(6, 3))

CO=[]
x=[]
for i in df['CO19']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    CO+=[i]

O3=[]
y=[]
for i in df['O319']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    O3+=[i]

ax.plot(df['Hour'], x, 'purple')
ax.scatter(df['Hour'], x,color='purple', label='$CO$ 2019')
plt.xticks(rotation=90)

ax2=ax.twinx()
ax2.plot(df['Hour'], y, 'red')
ax2.scatter(df['Hour'], y,color='red', label='$O_{3}$ 2019')

plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.ylim(0,100)
plt.xticks(rotation=90)

ax.set_xlabel('Hours')
ax.set_ylabel(r"CO  $[mg/m^{3}$]")
ax2.set_ylabel(r"$O_{3} \: [μg/m^{3}$]")
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)


ax.set_yticks(np.arange(0, 3.4, 0.4))
ax2.set_yticks(np.arange(0, 160, 20))
ax.set_ylim(0, 2.8)
ax2.set_ylim(0, 140)
ax.grid(linestyle='--', alpha=0.5)


plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(10))
plt.grid(linestyle='--', alpha=0.5)
plt.grid(which='minor', axis='y', linestyle='--', linewidth=0.5)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyparsing.helpers import PrecededBy
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Hourly/HPAT_BEN.csv'
df1 = pd.read_csv(url)
print(df1)
# Out:
#     Hour      BEN20
# 0    1:00  1.147727
# 1    2:00  1.032955
# 2    3:00  0.885682
# 3    4:00  0.851136
# 4    5:00  0.828636
# 5    6:00  0.949773
# 6    7:00  1.348409
# 7    8:00  2.052500
# 8    9:00  2.352045
# 9   10:00  1.906591
# 10  11:00  1.391136
# 11  12:00  1.199302
# 12  13:00  1.205000
# 13  14:00  1.237500
# 14  15:00  1.284545
# 15  16:00  1.202955
# 16  17:00  1.129545
# 17  18:00  1.017955
# 18  19:00  0.956136
# 19  20:00  0.990682
# 20  21:00  1.101136
# 21  22:00  1.226136
# 22  23:00  1.260227
# 23   0:00  1.341818

# %%
fig,ax = plt.subplots(figsize=(6, 3))


BEN=[]
x=[]
for i in df1['BEN20']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    BEN+=[i]


O3=[]
y=[]
for i in df['O32O']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    O3+=[i]



ax.plot(df['Hour'], x, 'black')
ax.scatter(df['Hour'], x,color='black', label='$C_{6}H_{6}$ 2020')
plt.xticks(rotation=90)

ax2=ax.twinx()
ax2.plot(df['Hour'], y, 'red')
ax2.scatter(df['Hour'], y,color='red', label='$O_{3}$ 2020')

plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.ylim(0,100)
plt.xticks(rotation=90)

ax.set_xlabel('Hours')
ax.set_ylabel(r"$C_{6}H_{6}$  $[μg/m^{3}$]")
ax2.set_ylabel(r"$O_{3} \: [μg/m^{3}$]")
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)

ax.set_yticks(np.arange(0, 4.4, 0.8))
ax2.set_yticks(np.arange(0, 110, 20))
ax.set_ylim(0, 4)
ax2.set_ylim(0, 100)
ax.grid(linestyle='--', alpha=0.5)
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(10))
plt.grid(linestyle='--', alpha=0.5)
plt.grid(which='minor', axis='y', linestyle='--', linewidth=0.5)
plt.show()

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Hourly/HPAT21.csv'
df21 = pd.read_csv(url)
print(df21)
# Out:
#      Hour       BEN         O3
# 0    1:00  1.762791  26.045455
# 1    2:00  1.534884  29.113636
# 2    3:00  1.281395  31.318182
# 3    4:00  1.153488  32.136364
# 4    5:00  1.030233  26.113636
# 5    6:00  1.116279  18.250000
# 6    7:00  1.597674  11.090909
# 7    8:00  2.918605   9.000000
# 8    9:00  3.702381  10.116279
# 9   10:00  3.707143  12.209302
# 10  11:00  3.176744  12.522727
# 11  12:00  2.572093  13.431818
# 12  13:00  2.641860  15.840909
# 13  14:00  2.880488  16.860465
# 14  15:00  3.065854  18.023256
# 15  16:00  2.816667  19.772727
# 16  17:00  2.376744  19.613636
# 17  18:00  2.255814  21.022727
# 18  19:00  2.295349  20.204545
# 19  20:00  2.306977  19.318182
# 20  21:00  2.516279  14.931818
# 21  22:00  2.750000  16.772727
# 22  23:00  2.329268  22.604651
# 23   0:00  1.907143  25.931818

# %%
fig,ax = plt.subplots(figsize=(6, 3))


BEN=[]
x=[]
for i in df21['BEN']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    BEN+=[i]


O3=[]
y=[]
for i in df21['O3']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    O3+=[i]



ax.plot(df21['Hour'], x, 'black')
ax.scatter(df21['Hour'], x,color='black', label='$C_{6}H_{6}$ 2021')
plt.xticks(rotation=90)

ax2=ax.twinx()
ax2.plot(df21['Hour'], y, 'red')
ax2.scatter(df21['Hour'], y,color='red', label='$O_{3}$ 2021')

plt.xlim(df21.loc[0]['Hour'] , df21.loc[23]['Hour'])
plt.ylim(0,100)
plt.xticks(rotation=90)

ax.set_xlabel('Hours')
ax.set_ylabel(r"$C_{6}H_{6}$  $[μg/m^{3}$]")
ax2.set_ylabel(r"$O_{3} \: [μg/m^{3}$]")
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)

ax.set_yticks(np.arange(0, 4.4, 0.8))
ax2.set_yticks(np.arange(0, 110, 20))
ax.set_ylim(0, 4)
ax2.set_ylim(0, 100)
ax.grid(linestyle='--', alpha=0.5)
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(10))
plt.grid(linestyle='--', alpha=0.5)
plt.grid(which='minor', axis='y', linestyle='--', linewidth=0.5)
plt.show()
