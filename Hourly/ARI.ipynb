# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Air-pollution-COVID-19-impact/blob/main/Hourly/ARI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyparsing.helpers import PrecededBy
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Hourly/HARI.csv'
df = pd.read_csv(url)
print(df)
# Out:
#      Hour       NO19       NO20      NO219      NO220     PM2519     PM2520
# 0    1:00  21.283333  11.466667  55.120000  30.866667  20.972973  15.866667
# 1    2:00  24.425000  10.633333  51.460000  29.700000  21.513514  14.500000
# 2    3:00  25.750000   9.866667  46.800000  26.666667  21.711712  15.400000
# 3    4:00  26.975000  10.666667  44.933333  27.500000  20.327273  14.366667
# 4    5:00  29.950000  14.800000  44.793333  29.700000  19.672727  14.166667
# 5    6:00  42.325000  30.700000  50.493333  36.966667  19.572727  15.633333
# 6    7:00  63.571429  44.600000  56.731544  41.100000  19.798165  15.766667
# 7    8:00  89.050000  50.366667  61.813333  45.200000  21.590909  16.433333
# 8    9:00  83.750000  48.100000  64.606667  47.233333  23.119266  15.566667
# 9   10:00  49.908333  29.766667  62.700000  44.833333  22.963303  16.200000
# 10  11:00  28.394958  15.966667  56.194631  40.200000  21.807339  12.900000
# ...

# %%
plt.figure(figsize=(6,3))

plt.xlabel('Hour')
plt.ylabel('$NO_{x}$  $[μg/m^{3}]$')

NO=[]
x=[]
for i in df['NO19']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    NO+=[i]

NO2=[]
xx=[]
for i in df['NO219']:
  if i==0:
    xx+=[None]
  else:
    xx+=[i]
    NO2+=[i]



plt.plot(df['Hour'], x, 'green')
plt.scatter(df['Hour'], x, color='green', label='$NO$ 2019')

plt.plot(df['Hour'], xx, 'orange')
plt.scatter(df['Hour'], xx,color='orange', label='$NO_{2}$ 2019')


plt.legend()

plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.ylim(0,100)

plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize=(6,3))

plt.xlabel('Hour')
plt.ylabel('$NO_{x}$  $[μg/m^{3}]$')

NO=[]
x=[]
for i in df['NO20']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    NO+=[i]

NO2=[]
xx=[]
for i in df['NO220']:
  if i==0:
    xx+=[None]
  else:
    xx+=[i]
    NO2+=[i]


plt.plot(df['Hour'], x, 'green')
plt.scatter(df['Hour'], x, color='green', label='$NO$ 2020')

plt.plot(df['Hour'], xx, 'orange')
plt.scatter(df['Hour'], xx,color='orange', label='$NO_{2}$ 2020')


plt.legend()

plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.ylim(0,60)

plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize=(6,3))

plt.xlabel('Hour')
plt.ylabel('$PM{2.5}$  $[μg/m^{3}]$')

PM25=[]
x=[]
for i in df['PM2519']:
  if i==0:
    PM25+=[None]
  else:
    x+=[i]
    PM25+=[i]

plt.plot(df['Hour'], x, 'cyan')
plt.scatter(df['Hour'], x, color='cyan', label='$NO$ 2019')

plt.legend()

plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.ylim(0,30)

plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize=(6,3))

plt.xlabel('Hour')
plt.ylabel('$PM{2.5}$  $[μg/m^{3}]$')

PM25=[]
x=[]
for i in df['PM2520']:
  if i==0:
    PM25+=[None]
  else:
    x+=[i]
    PM25+=[i]

plt.plot(df['Hour'], x, 'cyan')
plt.scatter(df['Hour'], x, color='cyan', label='$NO$ 2020')

plt.legend()

plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.ylim(0,30)

plt.xticks(rotation=90)

plt.show()
