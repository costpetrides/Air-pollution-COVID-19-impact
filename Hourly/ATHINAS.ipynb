# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Air-pollution-COVID-19-impact/blob/main/Hourly/ATHINAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyparsing.helpers import PrecededBy
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Hourly/HATH.csv'
df = pd.read_csv(url)
print(df)
# Out:
#      HOUR     NOMEAN       NO2O    NO2MEAN       NO220    COMEAN      CO20  \
# 0    1:00  32.897436   4.840909  54.785714   17.320000  0.526512  0.188372
# 1    2:00  38.897436   4.886364  53.722222   17.480000  0.548372  0.183721
# 2    3:00  35.282051   4.454545  50.412698   17.040000  0.517290  0.165116
# 3    4:00  31.846154   5.113636  44.825397   16.373333  0.432864  0.155814
# 4    5:00  28.641026   5.477273  41.349206   14.560000  0.392056  0.160465
# 5    6:00  34.820513  10.272727  42.626984   16.386667  0.433333  0.172093
# 6    7:00  58.736842  16.159091  48.168000   20.760000  0.518692  0.218605
# 7    8:00  77.102564  17.977273  53.452381   23.160000  0.700930  0.302326
# 8    9:00  68.736842  16.681818  57.201613   25.053333  0.848826  0.313953
# 9   10:00  43.157895  12.581395  56.880000 -108.786667  0.677830  0.030000
# 10  11:00  30.500000   8.204545  50.136000   18.760000  0.540376  0.202326
# ...

# %%
plt.figure(figsize=(6,3))

plt.xlabel('Hour')
plt.ylabel('$NO_{x}$  $[μg/m^{3}]$')

NO=[]
x=[]
for i in df['NO2O']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    NO+=[i]

NO2=[]
y=[]
for i in df['NO220']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    NO2+=[i]


O3MEAN=[]
xx=[]
for i in df['O320']:
  if i==0:
    xx+=[None]
  else:
    xx+=[i]
    O3MEAN+=[i]

plt.plot(df['HOUR'], xx, 'red')
plt.scatter(df['HOUR'], xx, color='red' ,label='$O_{3}$ Lockdown 2020')
plt.legend()

plt.plot(df['HOUR'], x, 'green')
plt.scatter(df['HOUR'], x, color='green', label='$NO$ Lockdown 2020')

plt.plot(df['HOUR'], y, 'orange')
plt.scatter(df['HOUR'], y,color='orange', label='$NO_{2}$ Lockdown 2020')

plt.legend()

plt.xlim(df.loc[0]['HOUR'] , df.loc[23]['HOUR'])
plt.ylim(0,100)

plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize=(6,3))

plt.xlabel('Hour')
plt.ylabel('$NO_{x}$  $[μg/m^{3}]$')

NO=[]
x=[]
for i in df['NOMEAN']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    NO+=[i]

NO2=[]
y=[]
for i in df['NO2MEAN']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    NO2+=[i]


O3MEAN=[]
xx=[]
for i in df['O3MEAN']:
  if i==0:
    xx+=[None]
  else:
    xx+=[i]
    O3MEAN+=[i]

plt.plot(df['HOUR'], xx, 'red')
plt.scatter(df['HOUR'], xx, color='red' ,label='$O_{3}$ 2016-19 ')
plt.legend()

plt.plot(df['HOUR'], x, 'green')
plt.scatter(df['HOUR'], x, color='green', label='$NO$ 2016-19')

plt.plot(df['HOUR'], y, 'orange')
plt.scatter(df['HOUR'], y,color='orange', label='$NO_{2}$ 2016-19 ')

plt.legend()

plt.xlim(df.loc[0]['HOUR'] , df.loc[23]['HOUR'])
plt.ylim(0,110)

plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize=(6,3))

plt.xlabel('Hour')
plt.ylabel('$CΟ$  $[mg/m^{3}]$')

CO=[]
x=[]
for i in df['COMEAN']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    CO+=[i]



O3MEAN=[]
xx=[]
for i in df['O3MEAN']:
  if i==0:
    xx+=[None]
  else:
    xx+=[i]
    O3MEAN+=[i]


plt.plot(df['HOUR'], xx, 'red')
plt.scatter(df['HOUR'], xx, color='red' ,label='$O_{3}$ 2016-19 ')
plt.legend()

plt.plot(df['HOUR'], x, 'purple')
plt.scatter(df['HOUR'], x, color='purple' ,label='$CO$ 2016-19')
plt.legend()

plt.xlim(df.loc[0]['HOUR'] , df.loc[23]['HOUR'])
plt.ylim(0,0.9)

plt.xticks(rotation=90)

plt.show()
