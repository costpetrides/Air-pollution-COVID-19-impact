# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Air-pollution-COVID-19-impact/blob/main/Hourly/GEO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyparsing.helpers import PrecededBy
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Hourly/HGEO.csv'
df = pd.read_csv(url)
print(df)
# Out:
#      Hour       NO19       NO2O      NO219      NO22O      CO19      CO2O  \
# 0    1:00  10.931034   1.357143  41.724138  24.035714  0.772414  0.478571
# 1    2:00   8.689655   1.758621  38.000000  22.172414  0.744828  0.479310
# 2    3:00   8.103448   1.285714  34.517241  19.964286  0.710345  0.450000
# 3    4:00   8.000000   1.111111  35.896552  17.111111  0.686207  0.437037
# 4    5:00  13.275862   1.000000  42.379310  19.344828  0.693103  0.389655
# 5    6:00  22.379310   3.821429  49.931034  27.250000  0.755172  0.392857
# 6    7:00  40.310345   8.178571  55.379310  36.892857  0.937931  0.450000
# 7    8:00  40.068966  23.857143  55.068966  42.000000  1.020690  0.639286
# 8    9:00  13.448276  20.259259  47.793103  42.481481  0.744828  0.581481
# 9   10:00   7.586207   9.185185  39.551724  34.555556  0.644828  0.514815
# 10  11:00   5.724138   3.538462  33.827586  23.423077  0.593103  0.480769
# 11  12:00   3.535714   3.680000  27.928571  20.760000  0.571429  0.548000
# 12  13:00   2.928571   2.120000  26.500000  15.440000  0.557143  0.565385
# 13  14:00   2.714286   1.703704  24.892857  12.518519  0.567857  0.548148
# 14  15:00   2.148148   1.555556  24.814815  11.777778  0.555556  0.522222
# 15  16:00   2.111111   1.407407  25.444444  10.814815  0.566667  0.503704
# 16  17:00   2.321429   1.333333  26.285714  10.481481  0.567857  0.470370
# 17  18:00   1.428571   1.142857  26.821429   9.178571  0.582143  0.442857
# 18  19:00   1.178571   1.000000  32.285714   9.185185  0.589286  0.440741
# 19  20:00   2.103448   1.000000  42.620690  11.703704  0.651724  0.437037
# 20  21:00   4.896552   1.000000  46.344828  14.821429  0.668966  0.442857
# 21  22:00   9.517241   1.074074  48.655172  17.629630  0.727586  0.470370
# 22  23:00   8.068966   1.000000  47.931034  21.607143  0.741379  0.478571
# 23   0:00   8.068966   1.107143  46.931034  25.071429  0.737931  0.492857
#
#           O319        O320
# 0    60.758621   63.571429
# 1    62.655172   64.172414
# 2    62.137931   62.428571
# 3    59.862069   63.259259
# 4    53.000000   57.862069
# 5    45.758621   49.392857
# 6    42.448276   39.142857
# 7    50.896552   37.370370
# 8    66.965517   43.740741
# 9    82.310345   60.222222
# 10   91.103448   77.846154
# 11   99.321429   81.769231
# 12  104.392857   90.640000
# 13  108.178571   97.555556
# 14  109.037037   99.333333
# 15  107.296296  101.629630
# 16  105.821429  101.888889
# 17  103.357143  102.142857
# 18   95.857143  100.555556
# 19   80.896552   95.925926
# 20   73.103448   89.107143
# 21   67.379310   80.888889
# 22   63.172414   71.571429
# 23   60.000000   65.000000

# %%
plt.figure(figsize=(5,3))

plt.xlabel('Hour')
plt.ylabel('$NO_{x}$  $[μg/m^{3}]$')

NO=[]
x=[]
for i in df['NO19']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    NO+=[i]

NO2=[]
xx=[]
for i in df['NO219']:
  if i==0:
    xx+=[None]
  else:
    xx+=[i]
    NO2+=[i]

O3=[]
y=[]
for i in df['O319']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    O3+=[i]

plt.plot(df['Hour'], x, 'green')
plt.scatter(df['Hour'], x, color='green', label='$NO$ 2019')

plt.plot(df['Hour'], xx, 'orange')
plt.scatter(df['Hour'], xx,color='orange', label='$NO_{2}$ 2019')

plt.plot(df['Hour'], y, 'red')
plt.scatter(df['Hour'], y,color='red', label='$O_{3}$ 2019')

plt.legend()
plt.grid(linestyle='--',alpha=0.5)

plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.ylim(0,120)
plt.xticks(rotation=90)
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(10))
plt.grid(linestyle='--', alpha=0.5)
plt.grid(which='minor', axis='y', linestyle='--', linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(5,3))

plt.xlabel('Hour')
plt.ylabel('$NO_{x}$  $[μg/m^{3}]$')

NO=[]
x=[]
for i in df['NO2O']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    NO+=[i]

NO2=[]
xx=[]
for i in df['NO22O']:
  if i==0:
    xx+=[None]
  else:
    xx+=[i]
    NO2+=[i]

O3=[]
y=[]
for i in df['O320']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    O3+=[i]

plt.plot(df['Hour'], x, 'green')
plt.scatter(df['Hour'], x, color='green', label='$NO$ 2020')

plt.plot(df['Hour'], xx, 'orange')
plt.scatter(df['Hour'], xx,color='orange', label='$NO_{2}$ 2020')

plt.plot(df['Hour'], y, 'red')
plt.scatter(df['Hour'], y,color='red', label='$O_{3}$ 2020')

plt.legend()
plt.grid(linestyle='--',alpha=0.5)
plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.ylim(0,120)

plt.xticks(rotation=90)
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(10))
plt.grid(linestyle='--', alpha=0.5)
plt.grid(which='minor', axis='y', linestyle='--', linewidth=0.5)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(5, 3))

CO=[]
x=[]
for i in df['CO19']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    CO+=[i]

O3=[]
y=[]
for i in df['O319']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    O3+=[i]

ax.plot(df['Hour'], x, 'purple')
ax.scatter(df['Hour'], x,color='purple', label='$CO$ 2019')
plt.xticks(rotation=90)

ax2=ax.twinx()
ax2.plot(df['Hour'], y, 'red')
ax2.scatter(df['Hour'], y,color='red', label='$O_{3}$ 2019')

plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.xticks(rotation=90)

ax.set_yticks(np.arange(0, 1.4, 0.2))
ax2.set_yticks(np.arange(0, 140, 20))
ax.set_ylim(0, 1.2)
ax2.set_ylim(0, 120)
ax.grid(linestyle='--', alpha=0.5)

ax.set_xlabel('Hours')
ax.set_ylabel(r"CO  $[mg/m^{3}$]")
ax2.set_ylabel(r"$O_{3} \: [μg/m^{3}$]")
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(10))
plt.grid(linestyle='--', alpha=0.5)
plt.grid(which='minor', axis='y', linestyle='--', linewidth=0.5)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(5, 3))

CO=[]
x=[]
for i in df['CO2O']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    CO+=[i]

O3=[]
y=[]
for i in df['O320']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    O3+=[i]

ax.plot(df['Hour'], x, 'purple')
ax.scatter(df['Hour'], x,color='purple', label='$CO$ 2020')
plt.xticks(rotation=90)

ax2=ax.twinx()
ax2.plot(df['Hour'], y, 'red')
ax2.scatter(df['Hour'], y,color='red', label='$O_{3}$ 2020')

plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.xticks(rotation=90)

ax.set_yticks(np.arange(0, 1.4, 0.2))
ax2.set_yticks(np.arange(0, 140, 20))
ax.set_ylim(0, 1.2)
ax2.set_ylim(0, 120)
ax.grid(linestyle='--', alpha=0.5)

ax.set_xlabel('Hours')
ax.set_ylabel(r"CO  $[mg/m^{3}$]")
ax2.set_ylabel(r"$O_{3} \: [μg/m^{3}$]")
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(10))
plt.grid(linestyle='--', alpha=0.5)
plt.grid(which='minor', axis='y', linestyle='--', linewidth=0.5)
plt.show()
