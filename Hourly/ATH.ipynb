# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Air-pollution-COVID-19-impact/blob/main/Hourly/ATH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyparsing.helpers import PrecededBy
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Hourly/HATH.csv'
df = pd.read_csv(url)
print(df)
# Out:
#      Hour       NO2O       NO19      NO22O      NO219       O319       O32O  \
# 0    1:00   4.800000  33.892857  13.600000  59.464286  27.785714  48.500000
# 1    2:00   4.733333  41.892857   9.366667  54.285714  30.500000  49.233333
# 2    3:00   4.266667  40.535714   8.666667  49.250000  32.785714  49.733333
# 3    4:00   4.866667  36.785714  10.566667  43.321429  36.392857  47.866667
# 4    5:00   5.166667  32.964286  12.200000  40.750000  36.571429  45.800000
# 5    6:00  10.500000  37.750000  17.933333  46.142857  28.178571  36.166667
# 6    7:00  17.366667  65.814815  22.066667  52.888889  20.555556  28.500000
# 7    8:00  18.033333  86.785714  18.733333  59.678571  16.285714  25.866667
# 8    9:00  16.700000  79.185185  19.900000  62.925926  19.370370  28.100000
# 9   10:00  10.833333  49.407407  21.466667  63.259259  28.555556  37.166667
# 10  11:00   8.066667  32.259259  18.733333  55.888889  42.370370  42.800000
# 11  12:00   7.666667  28.814815  17.700000  49.555556  50.629630  38.866667
# 12  13:00   6.633333  26.000000  13.700000  46.333333  56.518519  38.800000
# 13  14:00   5.500000  23.703704   8.866667  44.037037  61.555556  39.900000
# 14  15:00   5.533333  22.333333   8.766667  42.333333  65.037037  37.533333
# 15  16:00   5.733333  18.925926  10.166667  41.000000  67.925926  39.400000
# 16  17:00   5.633333  18.185185  10.700000  40.518519  66.111111  45.100000
# 17  18:00   5.233333  17.222222   9.366667  38.888889  67.185185  52.900000
# 18  19:00   4.800000  17.851852   7.866667  42.333333  61.555556  58.833333
# 19  20:00   4.366667  16.888889   7.333333  47.666667  54.259259  59.300000
# 20  21:00   4.700000  18.444444   9.000000  52.074074  46.666667  59.700000
# 21  22:00   7.266667  25.259259  14.866667  61.185185  34.703704  53.066667
# 22  23:00   6.033333  28.666667  17.466667  63.444444  30.592593  47.366667
# 23   0:00   5.733333  29.666667  17.233333  61.962963  28.037037  46.233333
#
#         CO19      CO2O
# 0   0.503571  0.190000
# 1   0.514286  0.176667
# 2   0.467857  0.160000
# 3   0.389286  0.156667
# 4   0.350000  0.160000
# 5   0.342857  0.163333
# 6   0.514815  0.223333
# 7   0.660714  0.316667
# 8   0.859259  0.320000
# 9   0.670370  0.246667
# 10  0.562963  0.213333
# 11  0.514815  0.226667
# 12  0.488889  0.216667
# 13  0.518519  0.206667
# 14  0.462963  0.193333
# 15  0.455556  0.186667
# 16  0.396296  0.176667
# 17  0.366667  0.140000
# 18  0.388889  0.133333
# 19  0.381481  0.136667
# 20  0.425926  0.163333
# 21  0.514815  0.183333
# 22  0.470370  0.210000
# 23  0.518519  0.210000

# %%
plt.figure(figsize=(5,3))

plt.xlabel('Hour')
plt.ylabel('$NO_{x}$  $[μg/m^{3}]$')

NO=[]
x=[]
for i in df['NO19']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    NO+=[i]

NO2=[]
xx=[]
for i in df['NO219']:
  if i==0:
    xx+=[None]
  else:
    xx+=[i]
    NO2+=[i]

O3=[]
y=[]
for i in df['O319']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    O3+=[i]

plt.plot(df['Hour'], x, 'green')
plt.scatter(df['Hour'], x, color='green', label='$NO$ 2019')

plt.plot(df['Hour'], xx, 'orange')
plt.scatter(df['Hour'], xx,color='orange', label='$NO_{2}$ 2019')

plt.plot(df['Hour'], y, 'red')
plt.scatter(df['Hour'], y,color='red', label='$O_{3}$ 2019')

plt.legend()
plt.grid(linestyle='--',alpha=0.5)
plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.ylim(0,100)

plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize=(5,3))

plt.xlabel('Hour')
plt.ylabel('$NO_{x}$  $[μg/m^{3}]$')

NO=[]
x=[]
for i in df['NO2O']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    NO+=[i]

NO2=[]
xx=[]
for i in df['NO22O']:
  if i==0:
    xx+=[None]
  else:
    xx+=[i]
    NO2+=[i]

O3=[]
y=[]
for i in df['O32O']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    O3+=[i]

plt.plot(df['Hour'], x, 'green')
plt.scatter(df['Hour'], x, color='green', label='$NO$ 2020')

plt.plot(df['Hour'], xx, 'orange')
plt.scatter(df['Hour'], xx,color='orange', label='$NO_{2}$ 2020')

plt.plot(df['Hour'], y, 'red')
plt.scatter(df['Hour'], y,color='red', label='$O_{3}$ 2020')

plt.legend()
plt.grid(linestyle='--',alpha=0.5)
plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.ylim(0,100)

plt.xticks(rotation=90)

plt.show()

# %%
fig,ax = plt.subplots(figsize=(5, 3))

CO=[]
x=[]
for i in df['CO19']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    CO+=[i]

O3=[]
y=[]
for i in df['O319']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    O3+=[i]

ax.plot(df['Hour'], x, 'purple')
ax.scatter(df['Hour'], x,color='purple', label='$CO$ 2019')
plt.xticks(rotation=90)

ax2=ax.twinx()
ax2.plot(df['Hour'], y, 'red')
ax2.scatter(df['Hour'], y,color='red', label='$O_{3}$ 2019')

plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.xticks(rotation=90)

ax.set_yticks(np.arange(0, 1.2, 0.2))
ax2.set_yticks(np.arange(0, 110, 20))
ax.set_ylim(0, 1)
ax2.set_ylim(0, 100)
ax.grid(linestyle='--', alpha=0.5)

ax.set_xlabel('Hours')
ax.set_ylabel(r"CO  $[mg/m^{3}$]")
ax2.set_ylabel(r"$O_{3} \: [μg/m^{3}$]")
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)

plt.show()

# %%
fig,ax = plt.subplots(figsize=(5, 3))

CO=[]
x=[]
for i in df['CO2O']:
  if i==0:
    x+=[None]
  else:
    x+=[i]
    CO+=[i]

O3=[]
y=[]
for i in df['O32O']:
  if i==0:
    y+=[None]
  else:
    y+=[i]
    O3+=[i]

ax.plot(df['Hour'], x, 'purple')
ax.scatter(df['Hour'], x,color='purple', label='$CO$ 2020')
plt.xticks(rotation=90)


ax2=ax.twinx()
ax2.plot(df['Hour'], y, 'red')
ax2.scatter(df['Hour'], y,color='red', label='$O_{3}$ 2020')

plt.xlim(df.loc[0]['Hour'] , df.loc[23]['Hour'])
plt.xticks(rotation=90)

ax.set_yticks(np.arange(0, 0.6, 0.1))
ax2.set_yticks(np.arange(0, 120, 20))
ax.set_ylim(0, 0.50)
ax2.set_ylim(0, 100)
ax.grid(linestyle='--', alpha=0.5)

ax.set_xlabel('Hours')
ax.set_ylabel(r"CO  $[mg/m^{3}$]")
ax2.set_ylabel(r"$O_{3} \: [μg/m^{3}$]")
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)

plt.show()
