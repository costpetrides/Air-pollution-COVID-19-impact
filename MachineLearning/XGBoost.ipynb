# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Air-pollution-COVID-19-impact/blob/main/MachineLearning/XGBoost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XGBoost - Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


import xgboost as xgb # XGBoost library :)

# %%
pip install xgboost optuna
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (3.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.11.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.12.0)
# Requirement already satisfied: cmaes>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (0.10.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.7.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.21)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)

# %%
# Import the data!

df=pd.read_csv('TestingData.csv')
cols = df.columns.tolist()
df.head()
# Out:
#    Mtemp  Htemp  Ltemp  Heat  Cool  Rain  WMSpeed  HWSpeed    NO    NO2  \
# 0   13.4   17.4    9.7   4.9   0.0   2.6      6.9     33.8  1.50  11.46
# 1   10.4   15.3    7.4   7.9   0.0   2.2      8.4     46.7  1.08  11.13
# 2    7.5   10.4    5.9  10.8   0.0   0.0      7.7     30.6  1.08   7.21
# 3    8.2   10.2    7.2  10.1   0.0   0.0      6.3     38.6  1.04   8.54
# 4    8.1   10.2    6.6  10.3   0.0   0.0      5.1     29.0  1.04   9.96
#
#    PM2.5     O3
# 0   4.71  81.79
# 1   4.08  72.00
# 2   7.23  73.50
# 3   8.71  74.17
# 4   9.17  72.17

# %%
cols = df.columns.tolist()    # Here we make a list with all labels names

# %%
# We split the data into training (60%), validation (20%), and test (20%) sets

train_end = int(0.7 * len(df))

train = df[:train_end]
test = df[train_end:]

train = df[:train_end]
test = df[train_end:]

# %%
# Scaling :)

def preprocess_data(dataframe):
    # Separate features and target variable
    x = dataframe.iloc[:, :-1].values
    y = dataframe.iloc[:, -1].values

    return x, y


# Apply preprocessing to your datasets
train_x, train_y = preprocess_data(train)
test_x, test_y = preprocess_data(test)

# %%
import optuna


def objective(trial):
    params = {
        'objective': 'reg:squaredlogerror',
        'eval_metric': 'rmse',
        'booster': 'gbtree',
        'verbosity': 0,
        'n_jobs': -1,
        'random_state': 42,
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
        'n_estimators': trial.suggest_int('n_estimators', 50, 500),
        'max_depth': trial.suggest_int('max_depth', 5, 30),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 20),
        'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
        'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
        'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
    }


    model = xgb.XGBRegressor(**params)

    # Train the model
    model.fit(train_x, train_y)

    # Make predictions on the test set
    pred_y = model.predict(test_x)

    # Evaluate the model on the test set using mean squared error
    mse = mean_squared_error(test_y, pred_y)

    return mse  # Optimize to minimize mean squared error

# Perform hyperparameter optimization with Optuna
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)

# Get the best hyperparameters
best_params = study.best_params

# Use the best hyperparameters in your program
best_model = xgb.XGBRegressor(**best_params)
best_model.fit(train_x, train_y)

# Now, you can use the best_model for predictions or any other tasks
# Out:
# [I 2023-10-16 17:37:35,128] A new study created in memory with name: no-name-3a0a9444-feee-49a9-8f35-1c5aebd8058d
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:35,258] Trial 0 finished with value: 8862.40075768177 and parameters: {'learning_rate': 0.14932513986244336, 'n_estimators': 405, 'max_depth': 6, 'min_child_weight': 11, 'subsample': 0.7543932456124278, 'colsample_bytree': 0.9378354961645317, 'gamma': 0.0004216671144236118, 'alpha': 1.5673505837478096e-06}. Best is trial 0 with value: 8862.40075768177.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:35,303] Trial 1 finished with value: 8568.291345169248 and parameters: {'learning_rate': 0.030800886987565956, 'n_estimators': 209, 'max_depth': 5, 'min_child_weight': 6, 'subsample': 0.7511238232494086, 'colsample_bytree': 0.7591927760692924, 'gamma': 0.007745636860268799, 'alpha': 0.22194059483740505}. Best is trial 1 with value: 8568.291345169248.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:35,372] Trial 2 finished with value: 8023.557197745687 and parameters: {'learning_rate': 0.14267840066947476, 'n_estimators': 81, 'max_depth': 18, 'min_child_weight': 3, 'subsample': 0.736507331203923, 'colsample_bytree': 0.8839606769464667, 'gamma': 0.2619155407221281, 'alpha': 0.0009194529865985832}. Best is trial 2 with value: 8023.557197745687.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:35,416] Trial 3 finished with value: 9095.08277292978 and parameters: {'learning_rate': 0.11605401396115166, 'n_estimators': 213, 'max_depth': 19, 'min_child_weight': 15, 'subsample': 0.7531927396908057, 'colsample_bytree': 0.9386098123987099, 'gamma': 0.3878922317263941, 'alpha': 0.26723959292547783}. Best is trial 2 with value: 8023.557197745687.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:35,504] Trial 4 finished with value: 8260.780067885393 and parameters: {'learning_rate': 0.08554860216811251, 'n_estimators': 366, 'max_depth': 23, 'min_child_weight': 4, 'subsample': 0.7643274708175166, 'colsample_bytree': 0.7010188783929105, 'gamma': 0.12984974678584718, 'alpha': 4.8151490772535594e-05}. Best is trial 2 with value: 8023.557197745687.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:35,582] Trial 5 finished with value: 8917.770264597855 and parameters: {'learning_rate': 0.2397359768269308, 'n_estimators': 274, 'max_depth': 14, 'min_child_weight': 14, 'subsample': 0.8460193528610198, 'colsample_bytree': 0.8565432413089726, 'gamma': 0.39315847114066094, 'alpha': 3.635934248765324e-05}. Best is trial 2 with value: 8023.557197745687.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:35,626] Trial 6 finished with value: 8940.462081748257 and parameters: {'learning_rate': 0.10647311617817581, 'n_estimators': 99, 'max_depth': 15, 'min_child_weight': 13, 'subsample': 0.9595479833025454, 'colsample_bytree': 0.9252685761979483, 'gamma': 2.922464830822677e-06, 'alpha': 8.4962336012828e-06}. Best is trial 2 with value: 8023.557197745687.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:35,665] Trial 7 finished with value: 8515.67452805047 and parameters: {'learning_rate': 0.16645244878308607, 'n_estimators': 70, 'max_depth': 15, 'min_child_weight': 7, 'subsample': 0.9515676682535725, 'colsample_bytree': 0.9532426072209184, 'gamma': 1.6312257487397563e-05, 'alpha': 5.436573215970653e-05}. Best is trial 2 with value: 8023.557197745687.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:35,736] Trial 8 finished with value: 8656.004386639335 and parameters: {'learning_rate': 0.2015253914949116, 'n_estimators': 370, 'max_depth': 12, 'min_child_weight': 8, 'subsample': 0.7355869774899064, 'colsample_bytree': 0.7944749738963323, 'gamma': 0.1629252776557305, 'alpha': 0.0001627823191450468}. Best is trial 2 with value: 8023.557197745687.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:35,814] Trial 9 finished with value: 8941.101447058354 and parameters: {'learning_rate': 0.39387995371322015, 'n_estimators': 318, 'max_depth': 14, 'min_child_weight': 20, 'subsample': 0.8642757170725757, 'colsample_bytree': 0.904950289779944, 'gamma': 0.045249161334088225, 'alpha': 0.00045399321790637245}. Best is trial 2 with value: 8023.557197745687.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:35,949] Trial 10 finished with value: 6853.72808570587 and parameters: {'learning_rate': 0.010291901986206173, 'n_estimators': 489, 'max_depth': 30, 'min_child_weight': 1, 'subsample': 0.8078224581493675, 'colsample_bytree': 0.9965003525434848, 'gamma': 0.0028374238506739444, 'alpha': 0.002144876592377075}. Best is trial 10 with value: 6853.72808570587.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:36,089] Trial 11 finished with value: 6844.3316747121735 and parameters: {'learning_rate': 0.011189595557160698, 'n_estimators': 493, 'max_depth': 30, 'min_child_weight': 1, 'subsample': 0.8108080590320861, 'colsample_bytree': 0.9834502428522083, 'gamma': 0.0034037288871840623, 'alpha': 0.004440691363058497}. Best is trial 11 with value: 6844.3316747121735.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:36,222] Trial 12 finished with value: 6818.4798591324325 and parameters: {'learning_rate': 0.01140787497125799, 'n_estimators': 478, 'max_depth': 30, 'min_child_weight': 1, 'subsample': 0.8222340528546714, 'colsample_bytree': 0.9971837206652607, 'gamma': 0.0020794256056936417, 'alpha': 0.008235602464958119}. Best is trial 12 with value: 6818.4798591324325.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:36,405] Trial 13 finished with value: 6843.243986973487 and parameters: {'learning_rate': 0.01117094627962852, 'n_estimators': 490, 'max_depth': 30, 'min_child_weight': 1, 'subsample': 0.8085059839025512, 'colsample_bytree': 0.9961061222299721, 'gamma': 0.0004660791718860387, 'alpha': 0.01570825114546315}. Best is trial 12 with value: 6818.4798591324325.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:36,534] Trial 14 finished with value: 8169.7076686861255 and parameters: {'learning_rate': 0.020889375638132805, 'n_estimators': 439, 'max_depth': 26, 'min_child_weight': 4, 'subsample': 0.8889568814061547, 'colsample_bytree': 0.995935999776652, 'gamma': 0.00027371262048910005, 'alpha': 0.011206532459346807}. Best is trial 12 with value: 6818.4798591324325.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:36,658] Trial 15 finished with value: 8862.315019148471 and parameters: {'learning_rate': 0.046075307817055884, 'n_estimators': 438, 'max_depth': 25, 'min_child_weight': 9, 'subsample': 0.7042133939876235, 'colsample_bytree': 0.9657739832725298, 'gamma': 0.00015050926986633797, 'alpha': 0.03158545128170191}. Best is trial 12 with value: 6818.4798591324325.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:36,794] Trial 16 finished with value: 6804.189519065412 and parameters: {'learning_rate': 0.0163555761762849, 'n_estimators': 455, 'max_depth': 22, 'min_child_weight': 1, 'subsample': 0.8056235536543653, 'colsample_bytree': 0.8973735421640364, 'gamma': 6.124803215719219e-05, 'alpha': 0.05018389526886608}. Best is trial 16 with value: 6804.189519065412.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:36,914] Trial 17 finished with value: 8347.559450639843 and parameters: {'learning_rate': 0.019308804751724452, 'n_estimators': 316, 'max_depth': 22, 'min_child_weight': 5, 'subsample': 0.9022220314598798, 'colsample_bytree': 0.8881548067926169, 'gamma': 5.717153022777615e-05, 'alpha': 0.06357412975915201}. Best is trial 16 with value: 6804.189519065412.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:37,040] Trial 18 finished with value: 9116.208563123553 and parameters: {'learning_rate': 0.047432477932333156, 'n_estimators': 432, 'max_depth': 27, 'min_child_weight': 17, 'subsample': 0.8346593955848639, 'colsample_bytree': 0.8485498004082205, 'gamma': 3.647152471375927e-05, 'alpha': 0.8465609907363849}. Best is trial 16 with value: 6804.189519065412.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:37,134] Trial 19 finished with value: 8883.625256194058 and parameters: {'learning_rate': 0.01703482856633157, 'n_estimators': 151, 'max_depth': 20, 'min_child_weight': 10, 'subsample': 0.7877698555337339, 'colsample_bytree': 0.9668403134502785, 'gamma': 1.0485484347811011e-06, 'alpha': 0.0044352753024807364}. Best is trial 16 with value: 6804.189519065412.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:37,258] Trial 20 finished with value: 8014.426317934861 and parameters: {'learning_rate': 0.02984438001871198, 'n_estimators': 391, 'max_depth': 27, 'min_child_weight': 3, 'subsample': 0.7869544077623698, 'colsample_bytree': 0.9295238541194284, 'gamma': 0.0014771274489465136, 'alpha': 0.07174363594644309}. Best is trial 16 with value: 6804.189519065412.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:37,417] Trial 21 finished with value: 6811.568708972162 and parameters: {'learning_rate': 0.013528256254491817, 'n_estimators': 496, 'max_depth': 30, 'min_child_weight': 1, 'subsample': 0.8223069219229954, 'colsample_bytree': 0.9980556523631725, 'gamma': 0.0006986098070958761, 'alpha': 0.014061801357602818}. Best is trial 16 with value: 6804.189519065412.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:37,545] Trial 22 finished with value: 7570.789186680895 and parameters: {'learning_rate': 0.014949879195961718, 'n_estimators': 449, 'max_depth': 23, 'min_child_weight': 2, 'subsample': 0.8286028945835618, 'colsample_bytree': 0.9668795736242487, 'gamma': 0.011690213221514346, 'alpha': 0.01212392796430177}. Best is trial 16 with value: 6804.189519065412.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:37,708] Trial 23 finished with value: 8496.915659627253 and parameters: {'learning_rate': 0.013787017151393804, 'n_estimators': 500, 'max_depth': 28, 'min_child_weight': 6, 'subsample': 0.8613387820935232, 'colsample_bytree': 0.9563080939481994, 'gamma': 0.0009555371840157348, 'alpha': 0.0032214394098411007}. Best is trial 16 with value: 6804.189519065412.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:37,848] Trial 24 finished with value: 8009.153853174606 and parameters: {'learning_rate': 0.023722498774510884, 'n_estimators': 455, 'max_depth': 25, 'min_child_weight': 3, 'subsample': 0.7854309698212871, 'colsample_bytree': 0.998909027790028, 'gamma': 0.00012186852666589085, 'alpha': 0.036641226885011494}. Best is trial 16 with value: 6804.189519065412.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# ...
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:50,125] Trial 92 finished with value: 7527.986096717279 and parameters: {'learning_rate': 0.026078229208571103, 'n_estimators': 204, 'max_depth': 29, 'min_child_weight': 2, 'subsample': 0.8972268301683515, 'colsample_bytree': 0.9095310077125163, 'gamma': 0.0012037446386332174, 'alpha': 0.0010041059210919021}. Best is trial 88 with value: 6707.275914420915.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:50,256] Trial 93 finished with value: 6723.15887153575 and parameters: {'learning_rate': 0.031745434724600216, 'n_estimators': 199, 'max_depth': 30, 'min_child_weight': 1, 'subsample': 0.8984931688893605, 'colsample_bytree': 0.9230370767233141, 'gamma': 0.001466508865347722, 'alpha': 0.0020537365542760825}. Best is trial 88 with value: 6707.275914420915.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:50,376] Trial 94 finished with value: 6715.032694081256 and parameters: {'learning_rate': 0.03306949085574844, 'n_estimators': 198, 'max_depth': 30, 'min_child_weight': 1, 'subsample': 0.9070813132125051, 'colsample_bytree': 0.9185420478340585, 'gamma': 0.001366998908219359, 'alpha': 0.00180827943817489}. Best is trial 88 with value: 6707.275914420915.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:50,497] Trial 95 finished with value: 7512.543825179569 and parameters: {'learning_rate': 0.03223852480035498, 'n_estimators': 189, 'max_depth': 30, 'min_child_weight': 2, 'subsample': 0.9084766947847203, 'colsample_bytree': 0.9224047933255002, 'gamma': 0.0014502976209086868, 'alpha': 0.0019386014176450692}. Best is trial 88 with value: 6707.275914420915.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:50,625] Trial 96 finished with value: 7932.820926739473 and parameters: {'learning_rate': 0.035829148452282904, 'n_estimators': 241, 'max_depth': 29, 'min_child_weight': 3, 'subsample': 0.8938880683943763, 'colsample_bytree': 0.9130486356996258, 'gamma': 0.0011170418530076468, 'alpha': 0.0010468192256929975}. Best is trial 88 with value: 6707.275914420915.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:50,750] Trial 97 finished with value: 6743.354128690499 and parameters: {'learning_rate': 0.02988939391054373, 'n_estimators': 163, 'max_depth': 30, 'min_child_weight': 1, 'subsample': 0.9041043078255269, 'colsample_bytree': 0.9011564073783143, 'gamma': 0.0021174585114465162, 'alpha': 0.0006983805769926883}. Best is trial 88 with value: 6707.275914420915.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:50,881] Trial 98 finished with value: 8185.017677186732 and parameters: {'learning_rate': 0.02997469973997599, 'n_estimators': 163, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.9144789753824942, 'colsample_bytree': 0.9054768731108909, 'gamma': 0.002187628138628271, 'alpha': 0.0003843720155939538}. Best is trial 88 with value: 6707.275914420915.
# <ipython-input-9-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-9-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-9-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-9-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-16 17:37:51,012] Trial 99 finished with value: 7903.840056467322 and parameters: {'learning_rate': 0.04211460791195157, 'n_estimators': 127, 'max_depth': 30, 'min_child_weight': 3, 'subsample': 0.8873387007192719, 'colsample_bytree': 0.899795629321154, 'gamma': 0.0031430344695962415, 'alpha': 0.0006942925532787164}. Best is trial 88 with value: 6707.275914420915.
# XGBRegressor(alpha=0.0006485469441481428, base_score=None, booster=None,
#              callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9230948957485807, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0.00025090231200854807,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.027183377401466056,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=30, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=445, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
pred_y = best_model.predict(test_x)

# Evaluate the model
mse = mean_squared_error(test_y, pred_y)
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Squared Error: 327.89

# %%
pred_y = best_model.predict(test_x)

# Evaluate the model
mae = mean_absolute_error(test_y, pred_y)
mse = mean_squared_error(test_y, pred_y)
r2 = r2_score(test_y, pred_y)

# Display the custom regression report
print("Custom Regression Report:")
print(f"Mean Absolute Error: {mae:.2f}")
print(f"Mean Squared Error: {mse:.2f}")
print(f"R-squared (R2): {r2:.2f}")
# Out:
# Custom Regression Report:
# Mean Absolute Error: 14.09
# Mean Squared Error: 327.89
# R-squared (R2): -0.13
