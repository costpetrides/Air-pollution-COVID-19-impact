# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Air-pollution-COVID-19-impact/blob/main/MachineLearning/XGBoost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # XGBoost - Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


import xgboost as xgb # XGBoost library :)

# %%
pip install xgboost optuna
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (3.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.11.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.12.0)
# Requirement already satisfied: cmaes>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (0.10.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.7.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.21)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)

# %%
# Import the data!

df=pd.read_csv('AGPATEST19.csv')
cols = df.columns.tolist()
df.head()
# Out:
#     NO   NO2  PM25    O3
# 0  1.5  11.5   4.7  81.8
# 1  1.1  11.1   4.1  72.0
# 2  1.1   7.2   7.2  73.5
# 3  1.0   8.5   8.7  74.2
# 4  1.0  10.0   9.2  72.2

# %%
cols = df.columns.tolist()    # Here we make a list with all labels names

# %%
# We split the data into training (60%), validation (20%), and test (20%) sets

train_end = int(0.7 * len(df))

train = df[:train_end]
test = df[train_end:]

train = df[:train_end]
test = df[train_end:]

# %%
# Scaling :)

def preprocess_data(dataframe):
    # Separate features and target variable
    x = dataframe.iloc[:, :-1].values
    y = dataframe.iloc[:, -1].values

    return x, y


# Apply preprocessing to your datasets
train_x, train_y = preprocess_data(train)
test_x, test_y = preprocess_data(test)

# %%
import optuna


def objective(trial):
    params = {
        'objective': 'reg:squaredlogerror',
        'eval_metric': 'rmse',
        'booster': 'gbtree',
        'verbosity': 0,
        'n_jobs': -1,
        'random_state': 42,
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
        'n_estimators': trial.suggest_int('n_estimators', 50, 500),
        'max_depth': trial.suggest_int('max_depth', 5, 30),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 20),
        'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
        'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
        'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
    }


    model = xgb.XGBRegressor(**params)

    # Train the model
    model.fit(train_x, train_y)

    # Make predictions on the test set
    pred_y = model.predict(test_x)

    # Evaluate the model on the test set using mean squared error
    mse = mean_squared_error(test_y, pred_y)

    return mse  # Optimize to minimize mean squared error

# Perform hyperparameter optimization with Optuna
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)

# Get the best hyperparameters
best_params = study.best_params

# Use the best hyperparameters in your program
best_model = xgb.XGBRegressor(**best_params)
best_model.fit(train_x, train_y)

# Now, you can use the best_model for predictions or any other tasks
# Out:
# [I 2023-10-14 12:25:30,809] A new study created in memory with name: no-name-986331e7-7eda-4d65-8b65-9a26856749e9
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:30,989] Trial 0 finished with value: 10872.265212210645 and parameters: {'learning_rate': 0.06316283913427446, 'n_estimators': 116, 'max_depth': 18, 'min_child_weight': 6, 'subsample': 0.9718568136118435, 'colsample_bytree': 0.8693450531637388, 'gamma': 0.006974542900134162, 'alpha': 0.003358268461199744}. Best is trial 0 with value: 10872.265212210645.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:31,047] Trial 1 finished with value: 11714.408259010275 and parameters: {'learning_rate': 0.0812764954511053, 'n_estimators': 290, 'max_depth': 21, 'min_child_weight': 16, 'subsample': 0.9274098914052924, 'colsample_bytree': 0.8998353311373076, 'gamma': 0.0010833035954770324, 'alpha': 7.462044517676133e-05}. Best is trial 0 with value: 10872.265212210645.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:31,077] Trial 2 finished with value: 11539.417317391302 and parameters: {'learning_rate': 0.10702076694948144, 'n_estimators': 131, 'max_depth': 16, 'min_child_weight': 12, 'subsample': 0.844713519801064, 'colsample_bytree': 0.770613001609182, 'gamma': 4.756597949116434e-06, 'alpha': 1.0422512021370646e-05}. Best is trial 0 with value: 10872.265212210645.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:31,146] Trial 3 finished with value: 11720.975159975182 and parameters: {'learning_rate': 0.04885027024661799, 'n_estimators': 434, 'max_depth': 27, 'min_child_weight': 15, 'subsample': 0.9171404649759267, 'colsample_bytree': 0.8110427414267037, 'gamma': 6.343848489920228e-06, 'alpha': 0.000240388838607036}. Best is trial 0 with value: 10872.265212210645.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:31,221] Trial 4 finished with value: 11201.850019370764 and parameters: {'learning_rate': 0.326092418141834, 'n_estimators': 438, 'max_depth': 18, 'min_child_weight': 7, 'subsample': 0.7386633042472472, 'colsample_bytree': 0.8215137961005046, 'gamma': 9.229027545685186e-06, 'alpha': 2.5187470427602107e-06}. Best is trial 0 with value: 10872.265212210645.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:31,303] Trial 5 finished with value: 11817.756705533584 and parameters: {'learning_rate': 0.01354133695970384, 'n_estimators': 410, 'max_depth': 8, 'min_child_weight': 15, 'subsample': 0.7833527524389886, 'colsample_bytree': 0.8377767069280286, 'gamma': 4.997690231316695e-05, 'alpha': 0.44337766341764107}. Best is trial 0 with value: 10872.265212210645.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:31,350] Trial 6 finished with value: 11794.861498722024 and parameters: {'learning_rate': 0.06079936030608132, 'n_estimators': 268, 'max_depth': 18, 'min_child_weight': 15, 'subsample': 0.8120433779140837, 'colsample_bytree': 0.7653064683106791, 'gamma': 2.8153992102255583e-05, 'alpha': 7.259006086687994e-05}. Best is trial 0 with value: 10872.265212210645.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:31,404] Trial 7 finished with value: 10934.444415675169 and parameters: {'learning_rate': 0.0412817666569651, 'n_estimators': 237, 'max_depth': 14, 'min_child_weight': 5, 'subsample': 0.7521999979443568, 'colsample_bytree': 0.790925302388602, 'gamma': 0.0016386567370920322, 'alpha': 0.0005425774466756288}. Best is trial 0 with value: 10872.265212210645.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:31,449] Trial 8 finished with value: 11811.592347891608 and parameters: {'learning_rate': 0.07502895083478023, 'n_estimators': 193, 'max_depth': 13, 'min_child_weight': 19, 'subsample': 0.9711090721921857, 'colsample_bytree': 0.7116655717971846, 'gamma': 0.005192326377024852, 'alpha': 0.02134536019226742}. Best is trial 0 with value: 10872.265212210645.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:31,523] Trial 9 finished with value: 9902.94868532347 and parameters: {'learning_rate': 0.06888400277709363, 'n_estimators': 395, 'max_depth': 29, 'min_child_weight': 2, 'subsample': 0.7275695956563962, 'colsample_bytree': 0.8168450545491805, 'gamma': 0.12464377655395349, 'alpha': 2.12646503609754e-06}. Best is trial 9 with value: 9902.94868532347.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:31,633] Trial 10 finished with value: 8906.527742786868 and parameters: {'learning_rate': 0.23006675848962113, 'n_estimators': 337, 'max_depth': 29, 'min_child_weight': 1, 'subsample': 0.7129509178108147, 'colsample_bytree': 0.9738718170891525, 'gamma': 0.23522018522146615, 'alpha': 1.2019028817889365e-06}. Best is trial 10 with value: 8906.527742786868.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:31,755] Trial 11 finished with value: 9905.518943353238 and parameters: {'learning_rate': 0.2639172772526078, 'n_estimators': 358, 'max_depth': 29, 'min_child_weight': 2, 'subsample': 0.7050432036767197, 'colsample_bytree': 0.9951446105726881, 'gamma': 0.3500452221292447, 'alpha': 2.6651758054954526e-06}. Best is trial 10 with value: 8906.527742786868.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:31,885] Trial 12 finished with value: 8951.64511027524 and parameters: {'learning_rate': 0.1823558332514923, 'n_estimators': 500, 'max_depth': 24, 'min_child_weight': 1, 'subsample': 0.7148705354203511, 'colsample_bytree': 0.9297124884328362, 'gamma': 0.44477080356018434, 'alpha': 1.0180580371945753e-06}. Best is trial 10 with value: 8906.527742786868.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:32,017] Trial 13 finished with value: 8835.353779926158 and parameters: {'learning_rate': 0.19538157817855364, 'n_estimators': 494, 'max_depth': 24, 'min_child_weight': 1, 'subsample': 0.7009266077988561, 'colsample_bytree': 0.9559302134313482, 'gamma': 0.9814115024494859, 'alpha': 1.0338400034972042e-06}. Best is trial 13 with value: 8835.353779926158.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:32,145] Trial 14 finished with value: 11283.294043356018 and parameters: {'learning_rate': 0.4185414620180029, 'n_estimators': 493, 'max_depth': 24, 'min_child_weight': 9, 'subsample': 0.768756107949606, 'colsample_bytree': 0.9947229681297195, 'gamma': 0.9787606465516085, 'alpha': 1.684206270414221e-05}. Best is trial 13 with value: 8835.353779926158.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:32,271] Trial 15 finished with value: 10167.45362216148 and parameters: {'learning_rate': 0.49126214158985076, 'n_estimators': 339, 'max_depth': 25, 'min_child_weight': 3, 'subsample': 0.7119273283458535, 'colsample_bytree': 0.9534607271101153, 'gamma': 0.06849798475642277, 'alpha': 1.534708559214283e-05}. Best is trial 13 with value: 8835.353779926158.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:32,381] Trial 16 finished with value: 10719.150241809419 and parameters: {'learning_rate': 0.16980103695095367, 'n_estimators': 325, 'max_depth': 30, 'min_child_weight': 4, 'subsample': 0.7001884401227725, 'colsample_bytree': 0.9566678978594021, 'gamma': 0.05156765676972391, 'alpha': 1.0298705422794374e-06}. Best is trial 13 with value: 8835.353779926158.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:32,453] Trial 17 finished with value: 11228.996430366671 and parameters: {'learning_rate': 0.21702704451924487, 'n_estimators': 57, 'max_depth': 22, 'min_child_weight': 9, 'subsample': 0.7841631646033912, 'colsample_bytree': 0.8847875598579688, 'gamma': 0.025433730017316674, 'alpha': 8.647664355132555e-06}. Best is trial 13 with value: 8835.353779926158.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:32,547] Trial 18 finished with value: 8907.2205128221 and parameters: {'learning_rate': 0.12733704306743981, 'n_estimators': 205, 'max_depth': 26, 'min_child_weight': 1, 'subsample': 0.7427429895678219, 'colsample_bytree': 0.916091352707164, 'gamma': 0.2460938272520512, 'alpha': 6.141152346325501e-05}. Best is trial 13 with value: 8835.353779926158.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:32,683] Trial 19 finished with value: 11370.229921800405 and parameters: {'learning_rate': 0.27387100902760536, 'n_estimators': 456, 'max_depth': 21, 'min_child_weight': 12, 'subsample': 0.8124540237474066, 'colsample_bytree': 0.863373679559546, 'gamma': 0.7600963907271416, 'alpha': 5.63335260897808e-06}. Best is trial 13 with value: 8835.353779926158.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:32,801] Trial 20 finished with value: 10941.409106252107 and parameters: {'learning_rate': 0.3530742189219903, 'n_estimators': 374, 'max_depth': 27, 'min_child_weight': 7, 'subsample': 0.7454034694018269, 'colsample_bytree': 0.9569189127110059, 'gamma': 0.02481862195763194, 'alpha': 2.363553213902244e-05}. Best is trial 13 with value: 8835.353779926158.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:32,888] Trial 21 finished with value: 8839.010618165781 and parameters: {'learning_rate': 0.1453205010668963, 'n_estimators': 206, 'max_depth': 26, 'min_child_weight': 1, 'subsample': 0.7402052803617891, 'colsample_bytree': 0.914079481996897, 'gamma': 0.1840541100338578, 'alpha': 6.422279878781921e-05}. Best is trial 13 with value: 8835.353779926158.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:32,985] Trial 22 finished with value: 10723.24863129364 and parameters: {'learning_rate': 0.16068653466360486, 'n_estimators': 163, 'max_depth': 30, 'min_child_weight': 4, 'subsample': 0.7036404712236769, 'colsample_bytree': 0.927964163765363, 'gamma': 0.16410950590083728, 'alpha': 3.817491849355157e-06}. Best is trial 13 with value: 8835.353779926158.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:33,120] Trial 23 finished with value: 10134.570855831458 and parameters: {'learning_rate': 0.2332094256265198, 'n_estimators': 306, 'max_depth': 27, 'min_child_weight': 3, 'subsample': 0.7367015203862403, 'colsample_bytree': 0.9806971009427937, 'gamma': 0.19390465302469687, 'alpha': 1.0659896256926652e-06}. Best is trial 13 with value: 8835.353779926158.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:33,236] Trial 24 finished with value: 8880.152930664515 and parameters: {'learning_rate': 0.1274878951328277, 'n_estimators': 262, 'max_depth': 23, 'min_child_weight': 1, 'subsample': 0.7643499688194529, 'colsample_bytree': 0.901532565396776, 'gamma': 0.6347694549712274, 'alpha': 5.297832730931571e-06}. Best is trial 13 with value: 8835.353779926158.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
# ...
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:42,892] Trial 92 finished with value: 8829.24531562951 and parameters: {'learning_rate': 0.20420990075998663, 'n_estimators': 478, 'max_depth': 24, 'min_child_weight': 1, 'subsample': 0.7002494754199982, 'colsample_bytree': 0.9409672264229518, 'gamma': 0.6611839497058717, 'alpha': 1.2828334184714318e-06}. Best is trial 37 with value: 8757.749295349557.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:43,075] Trial 93 finished with value: 9795.324090923858 and parameters: {'learning_rate': 0.20031564711765606, 'n_estimators': 490, 'max_depth': 25, 'min_child_weight': 2, 'subsample': 0.7006995418257771, 'colsample_bytree': 0.9399988691433016, 'gamma': 0.24829488256648286, 'alpha': 3.101520877224763e-06}. Best is trial 37 with value: 8757.749295349557.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:43,228] Trial 94 finished with value: 8904.056688973082 and parameters: {'learning_rate': 0.24291542437574726, 'n_estimators': 463, 'max_depth': 23, 'min_child_weight': 1, 'subsample': 0.7069096591320921, 'colsample_bytree': 0.9323109775384892, 'gamma': 0.35300286346678494, 'alpha': 1.231643333604876e-06}. Best is trial 37 with value: 8757.749295349557.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:43,398] Trial 95 finished with value: 9825.682588647864 and parameters: {'learning_rate': 0.17139804652226318, 'n_estimators': 434, 'max_depth': 25, 'min_child_weight': 2, 'subsample': 0.7211383443977277, 'colsample_bytree': 0.9451936210107118, 'gamma': 0.7684337699094023, 'alpha': 2.1021394830197434e-06}. Best is trial 37 with value: 8757.749295349557.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:43,557] Trial 96 finished with value: 9845.237897546314 and parameters: {'learning_rate': 0.22063924920033415, 'n_estimators': 484, 'max_depth': 26, 'min_child_weight': 2, 'subsample': 0.7141724691869161, 'colsample_bytree': 0.9363307990362497, 'gamma': 0.4592185205000197, 'alpha': 1.018990685887998e-06}. Best is trial 37 with value: 8757.749295349557.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:43,718] Trial 97 finished with value: 11562.483353755231 and parameters: {'learning_rate': 0.1932331529143044, 'n_estimators': 474, 'max_depth': 24, 'min_child_weight': 11, 'subsample': 0.7071791371621383, 'colsample_bytree': 0.9298563176416171, 'gamma': 0.18177361141519216, 'alpha': 3.2455473371375037e-06}. Best is trial 37 with value: 8757.749295349557.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:43,872] Trial 98 finished with value: 10313.45931066719 and parameters: {'learning_rate': 0.2793551901324439, 'n_estimators': 410, 'max_depth': 27, 'min_child_weight': 3, 'subsample': 0.7262429861194659, 'colsample_bytree': 0.9104572676721113, 'gamma': 0.6030727944920276, 'alpha': 8.7309201175085e-06}. Best is trial 37 with value: 8757.749295349557.
# <ipython-input-66-1b4db8ee6f85>:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.5),
# <ipython-input-66-1b4db8ee6f85>:16: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:17: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.7, 1.0),
# <ipython-input-66-1b4db8ee6f85>:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'gamma': trial.suggest_loguniform('gamma', 1e-6, 1.0),
# <ipython-input-66-1b4db8ee6f85>:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'alpha': trial.suggest_loguniform('alpha', 1e-6, 1.0),
# [I 2023-10-14 12:25:44,038] Trial 99 finished with value: 9856.082830508169 and parameters: {'learning_rate': 0.15624588268215647, 'n_estimators': 463, 'max_depth': 14, 'min_child_weight': 2, 'subsample': 0.7168162136864854, 'colsample_bytree': 0.9211309009911103, 'gamma': 0.3440409375074683, 'alpha': 4.134095385549476e-06}. Best is trial 37 with value: 8757.749295349557.
# XGBRegressor(alpha=2.352484214996506e-06, base_score=None, booster=None,
#              callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8426294049237657, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0.09880472578336905,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.09204221747502131,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=16, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=272, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
pred_y = best_model.predict(test_x)

# Evaluate the model
mse = mean_squared_error(test_y, pred_y)
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Squared Error: 4030.70

# %%
pred_y = best_model.predict(test_x)

# Evaluate the model
mae = mean_absolute_error(test_y, pred_y)
mse = mean_squared_error(test_y, pred_y)
r2 = r2_score(test_y, pred_y)

# Display the custom regression report
print("Custom Regression Report:")
print(f"Mean Absolute Error: {mae:.2f}")
print(f"Mean Squared Error: {mse:.2f}")
print(f"R-squared (R2): {r2:.2f}")
# Out:
# Custom Regression Report:
# Mean Absolute Error: 23.79
# Mean Squared Error: 4030.70
# R-squared (R2): -0.03
