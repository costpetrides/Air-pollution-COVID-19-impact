# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Air-pollution-COVID-19-impact/blob/main/Yearly/GEO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Γεωπονική B-Π (GEO)
#
#
# *   CO
# *   $0_{3}$
# *   NO
# *   $N0_{2}$

# %% [markdown]
# **Μονοξειδίου του άνθρακα CO**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 0.8, 0.6, 0.4, 0.4, 0.3, 0.4, 0.7, 0.7, 0.8, 0.8, 0.6, 0.9],    # G: years and S: months
         [ 1.2, 0.9, 0.7, 0.7, 0.4, 0.3, 0.3, 0.4, 0.5, 0.6, 0.7, 0.9],
         [ 0.8, 0.7, 0.6, 0.5, 0.5, 0.5, 0.3, 0.3, 0.3, 0.3,  -1, 0.3],
         [ 0.5, 0.6, 0.3, 0.3, 0.3, 0.4, 0.5, 0.5,  -1, 0.3, 0.6, 0.6]]

month=['Jan', 'Feb', 'Mar*', 'Apr**', 'May*', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov*', 'Dec*']     
year=['2018','2019','2020*','2021']

df_cm = pd.DataFrame(array, index = year, 
                     columns = month)

plt.figure(figsize = (10,7))


plt.title('$CO$')
sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': 'mg/$m^{3}$'}, cmap='Blues',fmt='g')

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %% [markdown]
# **Όζον $Ο_{3}$**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd

array = [[ 30, 45, 59, 68, 57, 67, 72, 79, 64, 45, 34, 26],    # G: years and S: months
         [ 44, 58, 74, 77, 60, 78, 84, 94, 77, 46, 35, 35],
         [ 42, 45, 52, 75, 68, 68, 83, 80, 72, 67, 80, 32],
         [ 33, 40, 64, 66, 64, 63, 87, 85, 75, 59, 36, 33]]
        

month=['Jan', 'Feb', 'Mar*', 'Apr**', 'May*', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov*', 'Dec*']      
year=['2018','2019','2020*','2021']

df_cm = pd.DataFrame(array, index = year, 
                     columns = month)

plt.figure(figsize = (10,7))


plt.title('$Ο_{3}$')
sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': 'μg/$m^{3}$'}, cmap='Blues',fmt='g')

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %% [markdown]
# **Mονοξειδίου του αζώτου NO**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 32, 15, 7, 6, 5, -1, 3, 2, 5, 20, 17, 31],    # G: years and S: months
         [ 45, 23, 17, 10, 8, 4, 3, 2, 8, 18, 30, 40],
         [ 34, 25, 11, 4, 7, 4, 2, 4, 4, 16, 13, 17],
         [ 26, 24 ,  7, 9, 6, 5, 3, 6, 7, -1, 16, 30]]

month=['Jan', 'Feb', 'Mar*', 'Apr**', 'May*', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov*', 'Dec*']      
year=['2018','2019','2020*','2021']

df_cm = pd.DataFrame(array, index = year, 
                     columns = month)

plt.figure(figsize = (10,7))


plt.title('$NO$')
sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': 'μg/$m^{3}$'}, cmap='Blues', fmt='g' )

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %% [markdown]
# **Διοξειδίου του αζώτου $ΝΟ_{2}$**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 34, 31, 21, 19, 16, -1, 33, 22, 28, 38, 32, 38],    # G: years and S: months
         [ 42, 34, 35, 39, 41, 34, 27, 18, 32, 41, 37, 36],
         [ 39, 37, 30, 21, 33, 26, 23, 25, 23, 34, 25, 27],
         [ 30, 35,  26, 30, 33, 31, 15, 30, 26, -1, 18, 21]]

month=['Jan', 'Feb', 'Mar*', 'Apr**', 'May*', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov*', 'Dec*']      
year=['2018','2019','2020*','2021']

df_cm = pd.DataFrame(array, index = year, 
                     columns = month)

plt.figure(figsize = (10,7))


plt.title('$NO_{2}$')
sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': 'μg/$m^{3}$'}, cmap='Blues', fmt='g' )

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')
