# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Air-pollution-COVID-19-impact/blob/main/Yearly/PAT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Patision U-T (PAT)
#
# *   $SO_{2}$
# *   CO
# *   $O_{3}$
# *   NO
# *   $NO_{2}$
# * $C_{6}H_{6}$

# %% [markdown]
# **$SO_{2}$**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 9, 9, 8, 12, 11, 12, 9, 5, 8, 5, None, None],    # G: years and S: months
         [ None, None, 5, 6, 8, 10, 8, 6, 6, 11, 10, 10],
         [ 16, 18, 14, 4, 4, 6, 4, 4, 5, 6, 6, 8],
         [ 7, 4, 4, 4, 6, 9, 5, 5, 6, 5, 7, 9]]

month=['Jan', 'Feb', 'Mar*', 'Apr**', 'May*', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov*', 'Dec*']      
year=['2018','2019','2020*','2021']

df_cm = pd.DataFrame(array, index = year, 
                     columns = month)

plt.figure(figsize = (10,7))


plt.title('$SO_{2}$')
sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': 'μg/$m^{3}$'}, cmap='Blues',fmt='g')

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
import pandas as pd
import matplotlib.pyplot as plt
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Yearly/Data-Y/Patision.csv'
df = pd.read_csv(url)

plt.figure(figsize=(17,5))

plt.xlabel('Day')
plt.ylabel('$SO_{2}$ μg/$m^{3}$]')
plt.title("$SO_{2}$  - Πατησίων")


plt.bar(df['DAY'], df['SO2'], label='$SO_{2}$ 2018-2021',ec='darkcyan')
plt.legend()


plt.xlim(df.loc[1]['DAY'] , df.loc[1460]['DAY'])
plt.ylim(0,30)

plt.xticks(df['DAY'][::102])

plt.axvline(x='22-Mar-18' ,color='b')
plt.axvline(x='4-May-18' ,color='b')

plt.axvline(x='22-Mar-19' ,color='b')
plt.axvline(x='4-May-19' ,color='b')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='b')
plt.axvline(x='4-May-21' ,color='b')


plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Yearly/Data-Y/Patision.csv'
df = pd.read_csv(url)

plt.figure(figsize=(17,5))

plt.xlabel('Day')
plt.ylabel('$SO_{2}$ μg/$m^{3}$]')
plt.title("$SO_{2}$  - Πατησίων")


x=[]
for i in  df['SO2']:
  if i==0:
    x+=[None]
  else:
    x+=[i]



plt.plot(df['DAY'], x, label='$SO_{2}$ 2018-2021')
plt.legend()


plt.xlim(df.loc[1]['DAY'] , df.loc[1460]['DAY'])
plt.ylim(0,30)

plt.xticks(df['DAY'][::102])

plt.axvline(x='22-Mar-18' ,color='g')
plt.axvline(x='4-May-18' ,color='g')

plt.axvline(x='22-Mar-19' ,color='g')
plt.axvline(x='4-May-19' ,color='g')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='g')
plt.axvline(x='4-May-21' ,color='g')


plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **CO**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 1.8, 1.4, 1.2, 1.2, 1, 1.1, 1.2, 0.8, 1.1, 1.3, None, None],    # G: years and S: months
         [ None, None, None, None, 2.0, 1.8, 0.8, 0.2, 1.1, 1.6, 1.5, 1.8],
         [ 1.5, 1.1, 0.7, 0.3, 0.9, 0.9, 0.6, 0.6, 0.8, 1.3, 0.9, 1.0],
         [ 1.3, 1.3, 1.0, 1.1, 1.2, 1.2, 0.7, 0.9, 0.9, 1.0, 1.4, 1.6]]

month=['Jan', 'Feb', 'Mar*', 'Apr**', 'May*', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov*', 'Dec*']     
year=['2018','2019','2020*','2021']

df_cm = pd.DataFrame(array, index = year, 
                     columns = month)

plt.figure(figsize = (10,7))


plt.title('$CO$')
sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': 'mg/$m^{3}$'}, cmap='Blues',fmt='g')

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
import pandas as pd
import matplotlib.pyplot as plt
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Yearly/Data-Y/Patision.csv'
df = pd.read_csv(url)

plt.figure(figsize=(17,5))

plt.xlabel('Day')
plt.ylabel('$CO$ mg/$m^{3}$]')
plt.title("$CO$  - Πατησίων")


plt.bar(df['DAY'], df['CO'], label= 'CO 2018-2021',ec='darkcyan')
plt.legend()


plt.xlim(df.loc[1]['DAY'] , df.loc[1460]['DAY'])
plt.ylim(0,5)

plt.xticks(df['DAY'][::102])

plt.axvline(x='22-Mar-18' ,color='b')
plt.axvline(x='4-May-18' ,color='b')

plt.axvline(x='22-Mar-19' ,color='b')
plt.axvline(x='4-May-19' ,color='b')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='b')
plt.axvline(x='4-May-21' ,color='b')


plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **$O_{3}$**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 23, 8, 5, 13, 11, 13, 7, 36, 28, 20, 23, 10],    # G: years and S: months
         [ 9, 14, 17, 15, 5, 12, 16, 30, 21, 8, 8, 6],
         [ 9, 11, 24, 40, 19, 29, 42, 36, 15, 7, 14, 10],
         [ 8, 13,  19, 19, 12, 15, 41, 33, 30, 26, 14, 11]]

month=['Jan', 'Feb', 'Mar*', 'Apr**', 'May*', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov*', 'Dec*']      
year=['2018','2019','2020*','2021']

df_cm = pd.DataFrame(array, index = year, 
                     columns = month)

plt.figure(figsize = (10,7))


plt.title('$Ο_{3}$')
sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': 'μg/$m^{3}$'}, cmap='Blues',fmt='g')

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
import pandas as pd
import matplotlib.pyplot as plt
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Yearly/Data-Y/Patision.csv'
df = pd.read_csv(url)

plt.figure(figsize=(17,5))

plt.xlabel('Day')
plt.ylabel('$O_{3}$ μg/$m^{3}$]')
plt.title("$O_{3}$  - Πατησίων")


plt.bar(df['DAY'], df['O3'], label='$O_{3}$ 2018-2021',ec='darkcyan')
plt.legend()


plt.xlim(df.loc[1]['DAY'] , df.loc[1460]['DAY'])
plt.ylim(0,100)

plt.xticks(df['DAY'][::102])

plt.axvline(x='22-Mar-18' ,color='b')
plt.axvline(x='4-May-18' ,color='b')

plt.axvline(x='22-Mar-19' ,color='b')
plt.axvline(x='4-May-19' ,color='b')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='b')
plt.axvline(x='4-May-21' ,color='b')


plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **NO**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 134, 85, 82, 81, 66, 64, 62, 30, 54, 76, 73, 115],    # G: years and S: months
         [ 94, 81 , 73, 59, 70, 49, 39, 18, 53, 97, 111, 136],
         [ 129, 102, 54, 21, 56, 65, 40, 40, 53, 97, 58, 66],
         [ 85, 88,  47, 54, 57, 66, 36, 44, 50, 58, 91, 106]]

month=['Jan', 'Feb', 'Mar*', 'Apr**', 'May*', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov*', 'Dec*']      
year=['2018','2019','2020*','2021']

df_cm = pd.DataFrame(array, index = year, 
                     columns = month)

plt.figure(figsize = (10,7))


plt.title('$NO$')
sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': 'μg/$m^{3}$'}, cmap='Blues', fmt='g' )

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
import pandas as pd
import matplotlib.pyplot as plt
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Yearly/Data-Y/Patision.csv'
df = pd.read_csv(url)

plt.figure(figsize=(17,5))

plt.xlabel('Day')
plt.ylabel('$NO$ μg/$μ^{3}$]')
plt.title("NO  - Πατησίων")


plt.bar(df['DAY'], df['NO'], label='ΝΟ 2018-2021',ec='darkcyan')
plt.legend()


plt.xlim(df.loc[1]['DAY'] , df.loc[1460]['DAY'])
plt.ylim(0,400)

plt.xticks(df['DAY'][::102])

plt.axvline(x='22-Mar-18' ,color='b')
plt.axvline(x='4-May-18' ,color='b')

plt.axvline(x='22-Mar-19' ,color='b')
plt.axvline(x='4-May-19' ,color='b')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='b')
plt.axvline(x='4-May-21' ,color='b')


plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **$NO_{2}$**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 74, 71, 80, 89, 76, 80, 88, 53, 65, 62, 53, 62],    # G: years and S: months
         [ 63, 62, 76, 74, 94, 85, 83, 61, 74, 76,67, 67],
         [ 73, 78, 62, 52, 82, 80, 70, 71, 71, 77, 47, 48],
         [ 59, 65,  65, 78, 82, 87, 73, 78, 72, 57, 65, 66]]

month=['Jan', 'Feb', 'Mar*', 'Apr**', 'May*', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov*', 'Dec*']      
year=['2018','2019','2020*','2021']

df_cm = pd.DataFrame(array, index = year, 
                     columns = month)

plt.figure(figsize = (10,7))


plt.title('$NO_{2}$')
sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': 'μg/$m^{3}$'}, cmap='Blues', fmt='g' )

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
import pandas as pd
import matplotlib.pyplot as plt
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Yearly/Data-Y/Patision.csv'
df = pd.read_csv(url)

plt.figure(figsize=(17,5))

plt.xlabel('Day')
plt.ylabel('$ΝO_{2}$ μg/$m^{3}$]')
plt.title("$ΝO_{2}$  - Πατησίων")


plt.bar(df['DAY'], df['NO2'], label='$ΝO_{2}$ 2018-2021',ec='darkcyan')
plt.legend()


plt.xlim(df.loc[1]['DAY'] , df.loc[1460]['DAY'])
plt.ylim(0,200)

plt.xticks(df['DAY'][::102])

plt.axvline(x='22-Mar-18' ,color='b')
plt.axvline(x='4-May-18' ,color='b')

plt.axvline(x='22-Mar-19' ,color='b')
plt.axvline(x='4-May-19' ,color='b')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='b')
plt.axvline(x='4-May-21' ,color='b')


plt.show()

# %% [markdown]
# ---

# %% [markdown]
# $C_{6}H_{6}$

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 6.9, 4.9, 5.2, 6.0, 6.4, 6.1, 6.4, 3.0, 6.4, 6.1,  None,  None],    # G: years and S: months
         [ 6.5, 5.4, 6.9, None,  None,  None,  None, 1.6, 1.5, 5.0, 5.6, 6.6],
         [ 5.8, 4.4, 2.6, 1.2, 3.2, 2.9, 2.6,  None, 4.9, 5.4, 3.5, 3.0],
         [ 4.7, 3.9, 2.0, 2.2, 2.7, 3.5, 2.3, 3.3, 2.8, 3.0, 4.5, 4.3]]

month=['Jan', 'Feb', 'Mar*', 'Apr**', 'May*', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov*', 'Dec*']      
year=['2018','2019','2020*','2021']

df_cm = pd.DataFrame(array, index = year, 
                     columns = month)

plt.figure(figsize = (10,7))


plt.title('$C_{6}H_{6}$')
sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': 'μg/$m^{3}$'}, cmap='Blues', fmt='g' )

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
import pandas as pd
import matplotlib.pyplot as plt
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Yearly/Data-Y/Patision.csv'
df = pd.read_csv(url)

plt.figure(figsize=(17,5))

plt.xlabel('Day')
plt.ylabel('$C_{6}H_{6}$ μg/$m^{3}$]')
plt.title("$C_{6}H_{6}$  - Πατησίων")


plt.bar(df['DAY'], df['BEN'], label='$C_{6}H_{6}$ 2018-2021',ec='darkcyan')
plt.legend()


plt.xlim(df.loc[1]['DAY'] , df.loc[1460]['DAY'])
plt.ylim(0,20)

plt.xticks(df['DAY'][::102])

plt.axvline(x='22-Mar-18' ,color='b')
plt.axvline(x='4-May-18' ,color='b')

plt.axvline(x='22-Mar-19' ,color='b')
plt.axvline(x='4-May-19' ,color='b')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='b')
plt.axvline(x='4-May-21' ,color='b')


plt.show()
