# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Air-pollution-COVID-19-impact/blob/main/Yearly/PAT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Patision U-T (PAT)
#
# *   $SO_{2}$
# *   CO
# *   $O_{3}$
# *   NO
# *   $NO_{2}$
# * $C_{6}H_{6}$

# %%
import pandas as pd
import matplotlib.pyplot as plt
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Yearly/Data-Y/Patision.csv'
df = pd.read_csv(url)
print(df)
# Out:
#             DAY  SO2  O3   CO   NO  NO2    BEN
# 0      1-Jan-18   13  19  3.3  243   67  14.11
# 1      2-Jan-18   10  16  1.8  156   77   7.33
# 2      3-Jan-18   10  16  1.8  144   75   6.77
# 3      4-Jan-18    9  16  1.4  113   71   5.50
# 4      5-Jan-18   15  17  2.6  203   91   9.55
# ...         ...  ...  ..  ...  ...  ...    ...
# 1456  27-Dec-21    8   4  1.6  117   67   4.17
# 1457  28-Dec-21    8  14  0.6   29   49   1.10
# 1458  29-Dec-21   10   4  2.1  178   66   5.96
# 1459  30-Dec-21    9   5  1.4   88   56   4.04
# 1460  31-Dec-21    7  16  1.0   48   48   1.93
#
# [1461 rows x 7 columns]

# %% [markdown]
# ---
#
#
# **$SO_{2}$**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 5, 5, 5,  8,  5,  3, 2, 2, 3, 3, 5, 6],
         [ 6, 7, 5,  6, 10,  5, 5, 3, 4, 4, 4, 9],
         [ 9, 9, 8, 12, 11, 12, 9, 5, 8, 5, None, None],    # G: years and S: months
         [ None, None,  5, 6, 8, 10, 8, 6, 6, 11, 10, 10],
         [ 16, 18, 14, 4, 4, 6, 4, 4, 5, 6, 6, 8],
         [ 7, 4, 4, 4, 6, 9, 5, 5, 6, 5, 7, 9],
         [ 10, 5, 5, 6, 7, 3, 3, 4, 4, 3, 3, 4]]

month=['Jan', 'Feb', 'Mar*', 'Apr**', 'May*', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov*', 'Dec*']
year=['2016','2017','2018','2019','2020*','2021','2022']

df_cm = pd.DataFrame(array, index = year,
                     columns = month)

plt.figure(figsize = (5,3))

sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': '$SO_{2} \:\: μg/m^{3}$'}, cmap='Blues',fmt='g')

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.patches as patches


# Define your data array
array = [[ 5,  5,  5,  8,  5,  3,  2,  2,  3,  3,  5,  6],
         [ 6,  7,  5,  6, 10,  5,  5,  3,  4,  4,  4,  9],
         [ 9,  9,  8, 12, 11, 12,  9,  5,  8,  5, None, None],
         [None, None,  5,  6,  8, 10,  8,  6,  6, 11, 10, 10],
         [16, 18, 14,  4,  4,  6,  4,  4,  5,  6,  6,  8],
         [ 7,  4,  4,  4,  6,  9,  5,  5,  6,  5,  7,  9],
         [10,  5,  5,  6,  7,  3,  3,  4,  4,  3,  3,  4]]

# Define labels for months and years
month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
year = ['2016', '2017', '2018', '2019', '2020', '2021', '2022']

# Create a DataFrame using pandas
df_cm = pd.DataFrame(array, index=year, columns=month)

# Set up the plot

plt.figure(figsize = (5,3))

# Create heatmap using seaborn
sns.heatmap(df_cm, annot=True, linewidth=0.5, cbar_kws={'label': '$SO_{2} \:\: μg/m^{3}$'}, cmap='Blues',fmt='g')

# Highlighting the cell 'April 2020'
target_year = '2020'
target_month = 'Apr'

# Find the index positions of the target year and month
target_year_index = df_cm.index.get_loc(target_year)
target_month_index = df_cm.columns.get_loc(target_month)

# Add a red border to the target cell
plt.gca().add_patch(patches.Rectangle((target_month_index, target_year_index), 1, 1, fill=False, edgecolor='red', lw=1))

# Save the plot as PNG and PDF files
plt.savefig('heatmap_highlighted.png')
plt.savefig('heatmap_highlighted.pdf')

# Display the plot
plt.show()

# %%
plt.figure(figsize=(13,2))

plt.xlabel('Days')
plt.ylabel('$SO_{2} \: [μg/m^{3}$]')


x=[]
for i in df['SO2']:
  if i==0:
    x+=[None]
  else:
    x+=[i]

plt.plot(df['DAY'], x, 'g', label='yearly')
plt.legend()

plt.xticks(['1-Jan-18','1-Feb-18','1-Mar-18','1-Apr-18','1-May-18','1-Jun-18','1-Jul-18','1-Aug-18','1-Sep-18','1-Oct-18','1-Nov-18','1-Dec-18','1-Jan-19','1-Feb-19','1-Mar-19','1-Apr-19','1-May-19','1-Jun-19','1-Jul-19','1-Aug-19','1-Sep-19','1-Oct-19','1-Nov-19','1-Dec-19','1-Jan-20','1-Feb-20','1-Mar-20','1-Apr-20','1-May-20','1-Jun-20','1-Jul-20','1-Aug-20','1-Sep-20','1-Oct-20','1-Nov-20','1-Dec-20' , '1-Jan-21', '1-Feb-21','1-Mar-21','1-Apr-21','1-May-21','1-Jun-21','1-Jul-21','1-Aug-21','1-Sep-21','1-Oct-21','1-Nov-21','1-Dec-21'])
plt.xticks(rotation=90)
plt.xlim('1-Jan-18' ,'31-Dec-21')
plt.ylim(0,30)

plt.axvline(x='22-Mar-18' ,color='b')
plt.axvline(x='4-May-18' ,color='b')

plt.axvline(x='22-Mar-19' ,color='b')
plt.axvline(x='4-May-19' ,color='b')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='b')
plt.axvline(x='4-May-21' ,color='b')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **CO**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[1.9, 1.9, 1.2, 1.5, 1.3, 1.4, 0.8, 0.8, 1.1, 1.3, 1.7, 1.6],
         [1.4, 1.3, 1.0, 1.0, 1.1, 1.6, 1.0, 0.6, 1.2, 1.3, 1.8, 2.0],
         [ 1.8, 1.4, 1.2, 1.2, 1, 1.1, 1.2, 0.8, 1.1, 1.3, None, None],    # G: years and S: months
         [ None, None, None, None, 2.0, 1.8, 0.8, 0.2, 1.1, 1.6, 1.5, 1.8],
         [ 1.5, 1.1, 0.7, 0.3, 0.9, 0.9, 0.6, 0.6, 0.8, 1.3, 0.9, 1.0],
         [ 1.3, 1.3, 1.0, 1.1, 1.2, 1.2, 0.7, 0.9, 0.9, 1.0, 1.4, 1.6],
         [1.7, 1.4, 1.0, 1.0, 1.1, 0.7, 0.4, 0.6, 1.0, 1.1, 1.6, 1.8]]

month=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
year=['2016','2017','2018','2019','2020','2021','2022']

df_cm = pd.DataFrame(array, index = year,
                     columns = month)

plt.figure(figsize = (5,3))

sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': '$CO \:\: mg/m^{3}$'}, cmap='Blues',fmt='g')

# Highlighting the cell 'April 2020'
target_year = '2020'
target_month = 'Apr'

# Find the index positions of the target year and month
target_year_index = df_cm.index.get_loc(target_year)
target_month_index = df_cm.columns.get_loc(target_month)

# Add a red border to the target cell
plt.gca().add_patch(patches.Rectangle((target_month_index, target_year_index), 1, 1, fill=False, edgecolor='red', lw=1))

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
plt.figure(figsize=(13,2))
plt.title("$CO$ - Aθηνάς")

plt.xlabel('Days')
plt.ylabel('$CO \: [mg/m^{3}$]')

plt.title("$CO$ - Πατησίων")

x=[]
for i in df['CO']:
  if i==0:
    x+=[None]
  else:
    x+=[i]

plt.plot(df['DAY'], x, 'g', label='yearly')
plt.legend()

plt.xticks(['1-Jan-18','1-Feb-18','1-Mar-18','1-Apr-18','1-May-18','1-Jun-18','1-Jul-18','1-Aug-18','1-Sep-18','1-Oct-18','1-Nov-18','1-Dec-18','1-Jan-19','1-Feb-19','1-Mar-19','1-Apr-19','1-May-19','1-Jun-19','1-Jul-19','1-Aug-19','1-Sep-19','1-Oct-19','1-Nov-19','1-Dec-19','1-Jan-20','1-Feb-20','1-Mar-20','1-Apr-20','1-May-20','1-Jun-20','1-Jul-20','1-Aug-20','1-Sep-20','1-Oct-20','1-Nov-20','1-Dec-20' , '1-Jan-21', '1-Feb-21','1-Mar-21','1-Apr-21','1-May-21','1-Jun-21','1-Jul-21','1-Aug-21','1-Sep-21','1-Oct-21','1-Nov-21','1-Dec-21'])
plt.xticks(rotation=90)
plt.xlim('1-Jan-18' ,'31-Dec-21')
plt.ylim(0,6)

plt.axvline(x='22-Mar-18' ,color='b')
plt.axvline(x='4-May-18' ,color='b')

plt.axvline(x='22-Mar-19' ,color='b')
plt.axvline(x='4-May-19' ,color='b')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='b')
plt.axvline(x='4-May-21' ,color='b')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **$O_{3}$**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 10,  9, 14, 10, 11, 21, None, 41, 29, 23, 14, 17],
         [ 19, 20, 23, 24, 21, 11, 32, 45, 7, 8, 7, 7],
         [ 23, 8, 5, 13, 11, 13, 7, 36, 28, 20, 23, 10],    # G: years and S: months
         [ 9, 14, 17, 15, 5, 12, 16, 30, 21, 8, 8, 6],
         [ 9, 11, 24, 40, 19, 29, 42, 36, 15, 7, 14, 10],
         [ 8, 13,  19, 19, 12, 15, 41, 33, 30, 26, 14, 11],
         [ 13, 12, 23, 20, 22, 31, 45, 32, 18, 20, 10, 6]]

month=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
year=['2016','2017','2018','2019','2020','2021','2022']

df_cm = pd.DataFrame(array, index = year,
                     columns = month)

plt.figure(figsize = (5,3))

sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': '$O_{3} \:\: μg/m^{3}$'}, cmap='Blues',fmt='g')

# Highlighting the cell 'April 2020'
target_year = '2020'
target_month = 'Apr'

# Find the index positions of the target year and month
target_year_index = df_cm.index.get_loc(target_year)
target_month_index = df_cm.columns.get_loc(target_month)

# Add a red border to the target cell
plt.gca().add_patch(patches.Rectangle((target_month_index, target_year_index), 1, 1, fill=False, edgecolor='red', lw=1))

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
plt.figure(figsize=(13,2))
plt.title("$O_{3}$ - Aθηνάς")

plt.xlabel('Days')
plt.ylabel('$O_{3} \: [μg/m^{3}$]')

plt.title("$O_{3}$ - Πατησίων")

x=[]
for i in df['O3']:
  if i==0:
    x+=[None]
  else:
    x+=[i]

plt.plot(df['DAY'], x, 'g', label='yearly')
plt.legend()

plt.xticks(['1-Jan-18','1-Feb-18','1-Mar-18','1-Apr-18','1-May-18','1-Jun-18','1-Jul-18','1-Aug-18','1-Sep-18','1-Oct-18','1-Nov-18','1-Dec-18','1-Jan-19','1-Feb-19','1-Mar-19','1-Apr-19','1-May-19','1-Jun-19','1-Jul-19','1-Aug-19','1-Sep-19','1-Oct-19','1-Nov-19','1-Dec-19','1-Jan-20','1-Feb-20','1-Mar-20','1-Apr-20','1-May-20','1-Jun-20','1-Jul-20','1-Aug-20','1-Sep-20','1-Oct-20','1-Nov-20','1-Dec-20' , '1-Jan-21', '1-Feb-21','1-Mar-21','1-Apr-21','1-May-21','1-Jun-21','1-Jul-21','1-Aug-21','1-Sep-21','1-Oct-21','1-Nov-21','1-Dec-21'])
plt.xticks(rotation=90)
plt.xlim('1-Jan-18' ,'31-Dec-21')
plt.ylim(0,200)

plt.axvline(x='22-Mar-18' ,color='b')
plt.axvline(x='4-May-18' ,color='b')

plt.axvline(x='22-Mar-19' ,color='b')
plt.axvline(x='4-May-19' ,color='b')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='b')
plt.axvline(x='4-May-21' ,color='b')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **NO**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 132, 126, 74, 87, 73, 75, 38, 37, 59, 67, 102, 110],
         [ 95, 104, 78, 77, 78, 102, 55, 24, 76, 85, 128, 150],
         [ 134, 85, 82, 81, 66, 64, 62, 30, 54, 76, 73, 115],    # G: years and S: months
         [ 94, 81 , 73, 59, 70, 49, 39, 18, 53, 97, 111, 136],
         [ 129, 102, 54, 21, 56, 65, 40, 40, 53, 97, 58, 66],
         [ 85, 88,  47, 54, 57, 66, 36, 44, 50, 58, 91, 106],
         [ 101, 100, 61, 55, 62, 38, 19, 26, 62, 68, 113, 134]]

month=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
year=['2016','2017','2018','2019','2020','2021','2022']

df_cm = pd.DataFrame(array, index = year,
                     columns = month)

plt.figure(figsize = (5,3))


sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': '$NO \:\: μg/m^{3}$'}, cmap='Blues', fmt='g' )

# Highlighting the cell 'April 2020'
target_year = '2020'
target_month = 'Apr'

# Find the index positions of the target year and month
target_year_index = df_cm.index.get_loc(target_year)
target_month_index = df_cm.columns.get_loc(target_month)

# Add a red border to the target cell
plt.gca().add_patch(patches.Rectangle((target_month_index, target_year_index), 1, 1, fill=False, edgecolor='red', lw=1))

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
plt.figure(figsize=(13,2))
plt.title("$NO$ - Πατησίων")

plt.xlabel('Days')
plt.ylabel('$NO \: [μg/m^{3}$]')


x=[]
for i in df['NO']:
  if i==0:
    x+=[None]
  else:
    x+=[i]

plt.plot(df['DAY'], x, 'g', label='yearly')
plt.legend()

plt.xticks(['1-Jan-18','1-Feb-18','1-Mar-18','1-Apr-18','1-May-18','1-Jun-18','1-Jul-18','1-Aug-18','1-Sep-18','1-Oct-18','1-Nov-18','1-Dec-18','1-Jan-19','1-Feb-19','1-Mar-19','1-Apr-19','1-May-19','1-Jun-19','1-Jul-19','1-Aug-19','1-Sep-19','1-Oct-19','1-Nov-19','1-Dec-19','1-Jan-20','1-Feb-20','1-Mar-20','1-Apr-20','1-May-20','1-Jun-20','1-Jul-20','1-Aug-20','1-Sep-20','1-Oct-20','1-Nov-20','1-Dec-20' , '1-Jan-21', '1-Feb-21','1-Mar-21','1-Apr-21','1-May-21','1-Jun-21','1-Jul-21','1-Aug-21','1-Sep-21','1-Oct-21','1-Nov-21','1-Dec-21'])
plt.xticks(rotation=90)
plt.xlim('1-Jan-18' ,'31-Dec-21')
plt.ylim(0,500)

plt.axvline(x='22-Mar-18' ,color='b')
plt.axvline(x='4-May-18' ,color='b')

plt.axvline(x='22-Mar-19' ,color='b')
plt.axvline(x='4-May-19' ,color='b')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='b')
plt.axvline(x='4-May-21' ,color='b')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **$NO_{2}$**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 64, 75, 73, 86, 85, 87, 63, 64, 65, 58, 63, 61],
         [ 60, 74, 81, 89, 93, 107, 86, 63, 82, 63, 64, 73],
         [ 74, 71, 80, 89, 76, 80, 88, 53, 65, 62, 53, 62],    # G: years and S: months
         [ 63, 62, 76, 74, 94, 85, 83, 61, 74, 76,67, 67],
         [ 73, 78, 62, 52, 82, 80, 70, 71, 71, 77, 47, 48],
         [ 59, 65,  65, 78, 82, 87, 73, 78, 72, 57, 65, 66],
         [ 62, 73, 71, 80, 81, 69, 60, 67, 77, 66, 64, 59]]

month=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
year=['2016','2017','2018','2019','2020','2021','2022']

df_cm = pd.DataFrame(array, index = year,
                     columns = month)

plt.figure(figsize = (5,3))


sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': '$NO_{2} \:\: μg/m^{3}$'}, cmap='Blues', fmt='g' )

# Highlighting the cell 'April 2020'
target_year = '2020'
target_month = 'Apr'

# Find the index positions of the target year and month
target_year_index = df_cm.index.get_loc(target_year)
target_month_index = df_cm.columns.get_loc(target_month)

# Add a red border to the target cell
plt.gca().add_patch(patches.Rectangle((target_month_index, target_year_index), 1, 1, fill=False, edgecolor='red', lw=1))

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
plt.figure(figsize=(13,2))
plt.title("$NO_{2}$ - Πατησίων")

plt.xlabel('Days')
plt.ylabel('$NO_{2} \: [μg/m^{3}$]')

plt.title("$NO_{2}$ - Aθηνάς")

x=[]
for i in df['NO2']:
  if i==0:
    x+=[None]
  else:
    x+=[i]

plt.plot(df['DAY'], x, 'g', label='yearly')
plt.legend()

plt.xticks(['1-Jan-18','1-Feb-18','1-Mar-18','1-Apr-18','1-May-18','1-Jun-18','1-Jul-18','1-Aug-18','1-Sep-18','1-Oct-18','1-Nov-18','1-Dec-18','1-Jan-19','1-Feb-19','1-Mar-19','1-Apr-19','1-May-19','1-Jun-19','1-Jul-19','1-Aug-19','1-Sep-19','1-Oct-19','1-Nov-19','1-Dec-19','1-Jan-20','1-Feb-20','1-Mar-20','1-Apr-20','1-May-20','1-Jun-20','1-Jul-20','1-Aug-20','1-Sep-20','1-Oct-20','1-Nov-20','1-Dec-20' , '1-Jan-21', '1-Feb-21','1-Mar-21','1-Apr-21','1-May-21','1-Jun-21','1-Jul-21','1-Aug-21','1-Sep-21','1-Oct-21','1-Nov-21','1-Dec-21'])
plt.xticks(rotation=90)
plt.xlim('1-Jan-18' ,'31-Dec-21')
plt.ylim(0,300)

plt.axvline(x='22-Mar-18' ,color='b')
plt.axvline(x='4-May-18' ,color='b')

plt.axvline(x='22-Mar-19' ,color='b')
plt.axvline(x='4-May-19' ,color='b')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='b')
plt.axvline(x='4-May-21' ,color='b')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# $C_{6}H_{6}$

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[7.6, 7.4, 4.1, 5.6, 5.4, 5.6, 3.3, 2.6, 4.7, 5.6, 7.6, 7.3],
         [6.1, 6.4, 4.9, 4.5, 5.3, 7.0, 4.1, 2.3, 6.0, 6.5, 8.6, 7.3],
         [ 6.9, 4.9, 5.2, 6.0, 6.4, 6.1, 6.4, 3.0, 6.4, 6.1,  None,  None],    # G: years and S: months
         [ 6.5, 5.4, 6.9, None,  None,  None,  None, 1.6, 1.5, 5.0, 5.6, 6.6],
         [ 5.8, 4.4, 2.6, 1.2, 3.2, 2.9, 2.6,  None, 4.9, 5.4, 3.5, 3.0],
         [ 4.7, 3.9, 2.0, 2.2, 2.7, 3.5, 2.3, 3.3, 2.8, 3.0, 4.5, 4.3],
         [3.9, 4.2, 2.8, 2.6, 3.4, 2.3, 1.6, 2.0, 3.6, 4.3, 6.0, 7.5]]

month=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
year=['2016','2017','2018','2019','2020','2021','2022']

df_cm = pd.DataFrame(array, index = year,
                     columns = month)

plt.figure(figsize = (5,3))


sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': '$C_{6}H_{6} \:\: μg/m^{3}$'}, cmap='Blues', fmt='g' )

# Highlighting the cell 'April 2020'
target_year = '2020'
target_month = 'Apr'

# Find the index positions of the target year and month
target_year_index = df_cm.index.get_loc(target_year)
target_month_index = df_cm.columns.get_loc(target_month)

# Add a red border to the target cell
plt.gca().add_patch(patches.Rectangle((target_month_index, target_year_index), 1, 1, fill=False, edgecolor='red', lw=1))

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
plt.figure(figsize=(15,3))
plt.title("$C_{6}H_{6}$ - Πατησίων")

plt.xlabel('Days')
plt.ylabel('$C_{6}H_{6} \: [μg/m^{3}$]')


x=[]
for i in df['BEN']:
  if i==0:
    x+=[None]
  else:
    x+=[i]

plt.plot(df['DAY'], x, 'g', label='yearly')
plt.legend()

plt.xticks(['1-Jan-18','1-Feb-18','1-Mar-18','1-Apr-18','1-May-18','1-Jun-18','1-Jul-18','1-Aug-18','1-Sep-18','1-Oct-18','1-Nov-18','1-Dec-18','1-Jan-19','1-Feb-19','1-Mar-19','1-Apr-19','1-May-19','1-Jun-19','1-Jul-19','1-Aug-19','1-Sep-19','1-Oct-19','1-Nov-19','1-Dec-19','1-Jan-20','1-Feb-20','1-Mar-20','1-Apr-20','1-May-20','1-Jun-20','1-Jul-20','1-Aug-20','1-Sep-20','1-Oct-20','1-Nov-20','1-Dec-20' , '1-Jan-21', '1-Feb-21','1-Mar-21','1-Apr-21','1-May-21','1-Jun-21','1-Jul-21','1-Aug-21','1-Sep-21','1-Oct-21','1-Nov-21','1-Dec-21'])
plt.xticks(rotation=90)
plt.xlim('1-Jan-18' ,'31-Dec-21')
plt.ylim(0,30)

plt.axvline(x='22-Mar-18' ,color='b')
plt.axvline(x='4-May-18' ,color='b')

plt.axvline(x='22-Mar-19' ,color='b')
plt.axvline(x='4-May-19' ,color='b')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='b')
plt.axvline(x='4-May-21' ,color='b')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# # **$NO_{2} - O_{3}$**

# %%
plt.figure(figsize=(13,2))

plt.xlabel('Days')
plt.ylabel('$ NO_{2} \:\: / \:\: O_{3} \:\:  [μg/m^{3}]$')


x=[]
for i in df['NO2']:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O3']:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.plot(df['DAY'], x, 'g', label='$NO_{2}$')
plt.plot(df['DAY'], y, 'b', label='$O_{3}$')
plt.legend()

plt.xticks(['1-Jan-18','1-Feb-18','1-Mar-18','1-Apr-18','1-May-18','1-Jun-18','1-Jul-18','1-Aug-18','1-Sep-18','1-Oct-18','1-Nov-18','1-Dec-18','1-Jan-19','1-Feb-19','1-Mar-19','1-Apr-19','1-May-19','1-Jun-19','1-Jul-19','1-Aug-19','1-Sep-19','1-Oct-19','1-Nov-19','1-Dec-19','1-Jan-20','1-Feb-20','1-Mar-20','1-Apr-20','1-May-20','1-Jun-20','1-Jul-20','1-Aug-20','1-Sep-20','1-Oct-20','1-Nov-20','1-Dec-20' , '1-Jan-21', '1-Feb-21','1-Mar-21','1-Apr-21','1-May-21','1-Jun-21','1-Jul-21','1-Aug-21','1-Sep-21','1-Oct-21','1-Nov-21','1-Dec-21'])
plt.xticks(rotation=90)
plt.xlim('1-Jan-18' ,'31-Dec-21')
plt.ylim(0,200)

plt.axvline(x='22-Mar-18' ,color='orange')
plt.axvline(x='4-May-18' ,color='orange')

plt.axvline(x='22-Mar-19' ,color='orange')
plt.axvline(x='4-May-19' ,color='orange')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='orange')
plt.axvline(x='4-May-21' ,color='orange')
plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize=(13,2))

plt.xlabel('Days')
plt.ylabel('$ NO \:\: / \:\: O_{3} \:\:  [μg/m^{3}]$')


x=[]
for i in df['NO']:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O3']:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.plot(df['DAY'], x, 'g', label='$NO$')
plt.plot(df['DAY'], y, 'b', label='$O_{3}$')
plt.legend()

plt.xticks(['1-Jan-18','1-Feb-18','1-Mar-18','1-Apr-18','1-May-18','1-Jun-18','1-Jul-18','1-Aug-18','1-Sep-18','1-Oct-18','1-Nov-18','1-Dec-18','1-Jan-19','1-Feb-19','1-Mar-19','1-Apr-19','1-May-19','1-Jun-19','1-Jul-19','1-Aug-19','1-Sep-19','1-Oct-19','1-Nov-19','1-Dec-19','1-Jan-20','1-Feb-20','1-Mar-20','1-Apr-20','1-May-20','1-Jun-20','1-Jul-20','1-Aug-20','1-Sep-20','1-Oct-20','1-Nov-20','1-Dec-20' , '1-Jan-21', '1-Feb-21','1-Mar-21','1-Apr-21','1-May-21','1-Jun-21','1-Jul-21','1-Aug-21','1-Sep-21','1-Oct-21','1-Nov-21','1-Dec-21'])
plt.xticks(rotation=90)
plt.xlim('1-Jan-18' ,'31-Dec-21')
plt.ylim(0,350)

plt.axvline(x='22-Mar-18' ,color='orange')
plt.axvline(x='4-May-18' ,color='orange')

plt.axvline(x='22-Mar-19' ,color='orange')
plt.axvline(x='4-May-19' ,color='orange')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='orange')
plt.axvline(x='4-May-21' ,color='orange')
plt.xticks(rotation=90)

plt.show()

# %%
fig,ax = plt.subplots(figsize=(14, 2))

x=[]
for i in df['CO']:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O3']:
  if i==0:
    y+=[None]
  else:
    y+=[i]


ax.plot(df['DAY'], x, 'g', label='$CO$ 2020')
plt.xticks(rotation=90)

ax2=ax.twinx()
ax2.plot(df['DAY'], y, 'b', label='$O_{3}$ 2020')


plt.xticks(['1-Jan-18','1-Feb-18','1-Mar-18','1-Apr-18','1-May-18','1-Jun-18','1-Jul-18','1-Aug-18','1-Sep-18','1-Oct-18','1-Nov-18','1-Dec-18','1-Jan-19','1-Feb-19','1-Mar-19','1-Apr-19','1-May-19','1-Jun-19','1-Jul-19','1-Aug-19','1-Sep-19','1-Oct-19','1-Nov-19','1-Dec-19','1-Jan-20','1-Feb-20','1-Mar-20','1-Apr-20','1-May-20','1-Jun-20','1-Jul-20','1-Aug-20','1-Sep-20','1-Oct-20','1-Nov-20','1-Dec-20' , '1-Jan-21', '1-Feb-21','1-Mar-21','1-Apr-21','1-May-21','1-Jun-21','1-Jul-21','1-Aug-21','1-Sep-21','1-Oct-21','1-Nov-21','1-Dec-21'])
plt.xticks(rotation=90)
plt.xlim('1-Jan-18' ,'31-Dec-21')


plt.xticks(rotation=90)

plt.axvline(x='22-Mar-18' ,color='orange')
plt.axvline(x='4-May-18' ,color='orange')

plt.axvline(x='22-Mar-19' ,color='orange')
plt.axvline(x='4-May-19' ,color='orange')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='orange')
plt.axvline(x='4-May-21' ,color='orange')

ax.set_xlabel('Days')
ax.set_ylabel(r"CO  $[mg/m^{3}$]")
ax2.set_ylabel(r"$O_{3} \: [μg/m^{3}$]")
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)

plt.show()

# %%
plt.figure(figsize=(13,2))

plt.xlabel('Days')
plt.ylabel('$SO_{2} \:\: / \:\: O_{3} \:\:  [μg/m^{3}]$')


x=[]
for i in df['SO2']:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O3']:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.plot(df['DAY'], x, 'g', label='$SO_{2}$')
plt.plot(df['DAY'], y, 'b', label='$O_{3}$')
plt.legend()

plt.xticks(['1-Jan-18','1-Feb-18','1-Mar-18','1-Apr-18','1-May-18','1-Jun-18','1-Jul-18','1-Aug-18','1-Sep-18','1-Oct-18','1-Nov-18','1-Dec-18','1-Jan-19','1-Feb-19','1-Mar-19','1-Apr-19','1-May-19','1-Jun-19','1-Jul-19','1-Aug-19','1-Sep-19','1-Oct-19','1-Nov-19','1-Dec-19','1-Jan-20','1-Feb-20','1-Mar-20','1-Apr-20','1-May-20','1-Jun-20','1-Jul-20','1-Aug-20','1-Sep-20','1-Oct-20','1-Nov-20','1-Dec-20' , '1-Jan-21', '1-Feb-21','1-Mar-21','1-Apr-21','1-May-21','1-Jun-21','1-Jul-21','1-Aug-21','1-Sep-21','1-Oct-21','1-Nov-21','1-Dec-21'])
plt.xticks(rotation=90)
plt.xlim('1-Jan-18' ,'31-Dec-21')
plt.ylim(0,100)

plt.axvline(x='22-Mar-18' ,color='orange')
plt.axvline(x='4-May-18' ,color='orange')

plt.axvline(x='22-Mar-19' ,color='orange')
plt.axvline(x='4-May-19' ,color='orange')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='orange')
plt.axvline(x='4-May-21' ,color='orange')
plt.xticks(rotation=90)

plt.show()
