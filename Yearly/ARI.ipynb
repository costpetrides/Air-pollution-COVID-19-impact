# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Air-pollution-COVID-19-impact/blob/main/Yearly/ARI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ARISTOTELOUS U-T (ARI)
#
#
#
#
# *   $SO_{2}$
# *   NO
# *   $NO_{2}$
# *   $PM_{2.5}$
# *   $PM_{10}$

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Yearly/Data-Y/Aristotelous.csv'
df = pd.read_csv(url)
print(df)
# Out:
#             DAY  PM25  PM10  SO2   NO  NO2
# 0      1-Jan-18    81   102    5  139   50
# 1      2-Jan-18    18    33    3   56   56
# 2      3-Jan-18    21    30    3   74   57
# 3      4-Jan-18    18    28    2   48   49
# 4      5-Jan-18    24    35    8  144   73
# ...         ...   ...   ...  ...  ...  ...
# 1456  27-Dec-21    19    39    8   63   33
# 1457  28-Dec-21    14    27    7   25   29
# 1458  29-Dec-21    21    33    9   90   33
# 1459  30-Dec-21    22    34    9   90   23
# 1460  31-Dec-21    17    22    6   41   25
#
# [1461 rows x 6 columns]

# %% [markdown]
# ---
# **$SO_{2}$**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 5, 4, 4, 8, 4, 6, 4, 3, 3, 3, 2, 5],
         [ 4, 6, 7, 7, 7, 6, 7, 3, 5, 3, 3, 3],
         [ 4, 3, 4, 7, 5, 6, 5, 3, None, None, None, None ],    # G: years and S: months
         [ None, None, None, None, None, None,  4, 2, 2, 3, 3, 3],
         [ 2, 4, None, 4, 7, 7, 6, 7, 9, None, 3, 6],
         [ 4, 3, 3, 3, 5, 4, 2, 3, 3, 2, 3, 6],
         [ 8, 2, 2, 3, 3, 3, 2, 3, 4, 5, 3, 3]]

month=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
year=['2016','2017','2018','2019','2020','2021','2022']

df_cm = pd.DataFrame(array, index = year,
                     columns = month)

plt.figure(figsize = (5,3))

sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': '$SO_{2} \:\: [μg/m^{3}]$'}, cmap='Blues',fmt='g')

# Highlighting the cell 'April 2020'
target_year = '2020'
target_month = 'Apr'

# Find the index positions of the target year and month
target_year_index = df_cm.index.get_loc(target_year)
target_month_index = df_cm.columns.get_loc(target_month)

# Add a red border to the target cell
plt.gca().add_patch(patches.Rectangle((target_month_index, target_year_index), 1, 1, fill=False, edgecolor='red', lw=1))

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
plt.figure(figsize=(13,2))

plt.xlabel('Day')
plt.ylabel('$SO_{2}$ μg/$μ^{3}$]')


x=[]
for i in df['SO2']:
  if i==0:
    x+=[None]
  else:
    x+=[i]

plt.plot(df['DAY'], x, label='SO2 2018-2021')
plt.legend()


plt.xlim(df.loc[1]['DAY'] , df.loc[1460]['DAY'])
plt.ylim(0,20)

plt.xticks(['1-Jan-18','1-Feb-18','1-Mar-18','1-Apr-18','1-May-18','1-Jun-18','1-Jul-18','1-Aug-18','1-Sep-18','1-Oct-18','1-Nov-18','1-Dec-18','1-Jan-19','1-Feb-19','1-Mar-19','1-Apr-19','1-May-19','1-Jun-19','1-Jul-19','1-Aug-19','1-Sep-19','1-Oct-19','1-Nov-19','1-Dec-19','1-Jan-20','1-Feb-20','1-Mar-20','1-Apr-20','1-May-20','1-Jun-20','1-Jul-20','1-Aug-20','1-Sep-20','1-Oct-20','1-Nov-20','1-Dec-20' , '1-Jan-21', '1-Feb-21','1-Mar-21','1-Apr-21','1-May-21','1-Jun-21','1-Jul-21','1-Aug-21','1-Sep-21','1-Oct-21','1-Nov-21','1-Dec-21' ])
plt.xticks(rotation=90)

plt.axvline(x='22-Mar-18' ,color='g')
plt.axvline(x='4-May-18' ,color='g')

plt.axvline(x='22-Mar-19' ,color='g')
plt.axvline(x='4-May-19' ,color='g')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='g')
plt.axvline(x='4-May-21' ,color='g')


plt.show()

# %% [markdown]
# ---
# **NO**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 75, 60, 25, 28, 13, 20, 11, 12, 24, 35, 63, 74],
         [ 68, 58, 34, 25, 19, 28, 19, 12, 20, None, None, 86],
         [ 71, 19, 21, 28, 18, 13, 11, 13, 23, 45, 50, 77],    # G: years and S: months
         [ 56, 52, 34, 26, 19, 16, 12,  8, 24, 52, 71, 85],
         [ 89, 55, 37, 14, 25, 15,  9, 15, 17, 50, 40, 43],
         [ 52, 60, 19, 18, 15, 15, None, None, 29, 30,  56, 67],
         [83, 54, 37, 18, 18, 13, 13, 13, 27, 46, 61, 80]]

month=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
year=['2016','2017','2018','2019','2020','2021','2022']

df_cm = pd.DataFrame(array, index = year,
                     columns = month)

plt.figure(figsize = (5,3))

sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': 'NO $\:\: [μg/m^{3}]$'}, cmap='Blues',fmt='g')

# Highlighting the cell 'April 2020'
target_year = '2020'
target_month = 'Apr'

# Find the index positions of the target year and month
target_year_index = df_cm.index.get_loc(target_year)
target_month_index = df_cm.columns.get_loc(target_month)

# Add a red border to the target cell
plt.gca().add_patch(patches.Rectangle((target_month_index, target_year_index), 1, 1, fill=False, edgecolor='red', lw=1))

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
plt.figure(figsize=(13,2))

plt.xlabel('Day')
plt.ylabel('$NO$ μg/$μ^{3}$]')

x=[]
for i in df['NO']:
  if i==0:
    x+=[None]
  else:
    x+=[i]

plt.plot(df['DAY'], x, label='ΝΟ 2018-2021')
plt.legend()


plt.xlim(df.loc[1]['DAY'] , df.loc[1460]['DAY'])
plt.ylim(0,300)

plt.xticks(['1-Jan-18','1-Feb-18','1-Mar-18','1-Apr-18','1-May-18','1-Jun-18','1-Jul-18','1-Aug-18','1-Sep-18','1-Oct-18','1-Nov-18','1-Dec-18','1-Jan-19','1-Feb-19','1-Mar-19','1-Apr-19','1-May-19','1-Jun-19','1-Jul-19','1-Aug-19','1-Sep-19','1-Oct-19','1-Nov-19','1-Dec-19','1-Jan-20','1-Feb-20','1-Mar-20','1-Apr-20','1-May-20','1-Jun-20','1-Jul-20','1-Aug-20','1-Sep-20','1-Oct-20','1-Nov-20','1-Dec-20' , '1-Jan-21', '1-Feb-21','1-Mar-21','1-Apr-21','1-May-21','1-Jun-21','1-Jul-21','1-Aug-21','1-Sep-21','1-Oct-21','1-Nov-21','1-Dec-21' ])
plt.xticks(rotation=90)

plt.axvline(x='22-Mar-18' ,color='g')
plt.axvline(x='4-May-18' ,color='g')

plt.axvline(x='22-Mar-19' ,color='g')
plt.axvline(x='4-May-19' ,color='g')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='g')
plt.axvline(x='4-May-21' ,color='g')


plt.show()

# %% [markdown]
# ---
# **$ΝΟ_{2}$**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 47, 50, 44, 50, 42, 46, 41, 38, 49, 51, 53, 53],
         [ 51, 56, 58, 56, 54, 64, 52, 42, 56, None, None, 56 ],
         [ 55, 49, 48, 61, 50, 46, 48, 39, 48, 46, 41, 46],    # G: years and S: months
         [ 43, 44, 45, 49, 45, 42, 45, 35, 46, 49, 34, 34 ],
         [ 44, 46, 40, 33, 43, 37, 42, 38, 37, 37, 35, 38],
         [ 41, 48, 39, 42, 48, 47, None, None, 53, 45, 48, 33],
         [ 36, 53, 54, 45, 51, 44, 44, 39, 47, 51, 50, 50]]

month=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
year=['2016','2017','2018','2019','2020','2021','2022']

df_cm = pd.DataFrame(array, index = year,
                     columns = month)

plt.figure(figsize = (5,3))

sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': '$NO_{2}  \:\: [μg/m^{3}]$'}, cmap='Blues',fmt='g')

# Highlighting the cell 'April 2020'
target_year = '2020'
target_month = 'Apr'

# Find the index positions of the target year and month
target_year_index = df_cm.index.get_loc(target_year)
target_month_index = df_cm.columns.get_loc(target_month)

# Add a red border to the target cell
plt.gca().add_patch(patches.Rectangle((target_month_index, target_year_index), 1, 1, fill=False, edgecolor='red', lw=1))

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
plt.figure(figsize=(13,2))

plt.xlabel('Day')
plt.ylabel('$ΝO_{2}$ μg/$m^{3}$]')


x=[]
for i in df['NO2']:
  if i==0:
    x+=[None]
  else:
    x+=[i]

plt.plot(df['DAY'], x, label='$ΝO_{2}$ 2018-2021')
plt.legend()


plt.xlim(df.loc[1]['DAY'] , df.loc[1460]['DAY'])
plt.ylim(0,100)

plt.xticks(['1-Jan-18','1-Feb-18','1-Mar-18','1-Apr-18','1-May-18','1-Jun-18','1-Jul-18','1-Aug-18','1-Sep-18','1-Oct-18','1-Nov-18','1-Dec-18','1-Jan-19','1-Feb-19','1-Mar-19','1-Apr-19','1-May-19','1-Jun-19','1-Jul-19','1-Aug-19','1-Sep-19','1-Oct-19','1-Nov-19','1-Dec-19','1-Jan-20','1-Feb-20','1-Mar-20','1-Apr-20','1-May-20','1-Jun-20','1-Jul-20','1-Aug-20','1-Sep-20','1-Oct-20','1-Nov-20','1-Dec-20' , '1-Jan-21', '1-Feb-21','1-Mar-21','1-Apr-21','1-May-21','1-Jun-21','1-Jul-21','1-Aug-21','1-Sep-21','1-Oct-21','1-Nov-21','1-Dec-21' ])
plt.xticks(rotation=90)

plt.axvline(x='22-Mar-18' ,color='g')
plt.axvline(x='4-May-18' ,color='g')

plt.axvline(x='22-Mar-19' ,color='g')
plt.axvline(x='4-May-19' ,color='g')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='g')
plt.axvline(x='4-May-21' ,color='g')


plt.show()

# %% [markdown]
# ---
# **$PM_{2.5}$**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 31, 25, 20, 19, 16, 16, 14, 16, 16, 17, 23, 26],
         [ 24, 26, 20, 17, 15, 20, 16, 15, 15, 16, 26, 23],
         [ 30, 18, 18, 21, 17, 15, 17, 14, 14, 21, 18, 27],    # G: years and S: months
         [ 24, 24, 20, 21, 16, 17, 15, 14, 16, 23, 20, 24],
         [ 28, 20, 17, 14, 15, 11, 14, 14, 13, 14, 17, 17],
         [ 20, 25, 16, 17, 15, 17, 16, 22, 16, 14, 24, 20],
         [ 27, 24, 21, 17, 17, 16, 14, 16, 15, 17, 20, 28]]

month=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
year=['2016','2017','2018','2019','2020','2021','2022']

df_cm = pd.DataFrame(array, index = year,
                     columns = month)

plt.figure(figsize = (5,3))


sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': ' $PM_{2.5} \:\: [μg/m^{3}]$'}, cmap='Blues',fmt='g')

# Highlighting the cell 'April 2020'
target_year = '2020'
target_month = 'Apr'

# Find the index positions of the target year and month
target_year_index = df_cm.index.get_loc(target_year)
target_month_index = df_cm.columns.get_loc(target_month)

# Add a red border to the target cell
plt.gca().add_patch(patches.Rectangle((target_month_index, target_year_index), 1, 1, fill=False, edgecolor='red', lw=1))

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
plt.figure(figsize=(13,2))

plt.xlabel('Day')
plt.ylabel('$PM_{2.5}$ μg/$m^{3}$]')


x=[]
for i in df['PM25']:
  if i==0:
    x+=[None]
  else:
    x+=[i]



plt.plot(df['DAY'], x, label='$PM_{2.5}$ 2018-2021')
plt.legend()


plt.xlim(df.loc[1]['DAY'] , df.loc[1460]['DAY'])
plt.ylim(0,95)

plt.xticks(['1-Jan-18','1-Feb-18','1-Mar-18','1-Apr-18','1-May-18','1-Jun-18','1-Jul-18','1-Aug-18','1-Sep-18','1-Oct-18','1-Nov-18','1-Dec-18','1-Jan-19','1-Feb-19','1-Mar-19','1-Apr-19','1-May-19','1-Jun-19','1-Jul-19','1-Aug-19','1-Sep-19','1-Oct-19','1-Nov-19','1-Dec-19','1-Jan-20','1-Feb-20','1-Mar-20','1-Apr-20','1-May-20','1-Jun-20','1-Jul-20','1-Aug-20','1-Sep-20','1-Oct-20','1-Nov-20','1-Dec-20' , '1-Jan-21', '1-Feb-21','1-Mar-21','1-Apr-21','1-May-21','1-Jun-21','1-Jul-21','1-Aug-21','1-Sep-21','1-Oct-21','1-Nov-21','1-Dec-21' ])
plt.xticks(rotation=90)

plt.axvline(x='22-Mar-18' ,color='g')
plt.axvline(x='4-May-18' ,color='g')

plt.axvline(x='22-Mar-19' ,color='g')
plt.axvline(x='4-May-19' ,color='g')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='g')
plt.axvline(x='4-May-21' ,color='g')


plt.show()

# %% [markdown]
# ___
# **$PM_{10}$**

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd


array = [[ 48, 47, 45, 52, 44, 43, 32, 36, 35, 31, 39, 41 ],
         [ 41, 43, 33, 30, 30, 38, 34, 35, 34, 30, 45, 38],
         [ 38, 31, 47, 42, 36, 32, 33, 33, 31, 40, 32, 40],    # G: years and S: months
         [ 42, 35, 37, 39, 31, 34, 29, 30, 35, 42, 42, 42],
         [ 46, 35, 32, 25, 34, 25, 29, 29, 31, 31, None, 30],
         [ 37, 42, 27, 31, 30, 29, 31, 36, 32, 26, 40, 34],
         [ 40, 42, 37, 41, 33, 30, 33, 30, 30, 31, 36, 47]]

month=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
year=['2016','2017','2018','2019','2020','2021','2022']

df_cm = pd.DataFrame(array, index = year,
                     columns = month)

plt.figure(figsize = (5,3))


sn.heatmap(df_cm, annot=True, linewidth=0.01, cbar_kws={'label': ' $PM_{10} \:\: [μg/m^{3}]$'}, cmap='Blues',fmt='g')

# Highlighting the cell 'April 2020'
target_year = '2020'
target_month = 'Apr'

# Find the index positions of the target year and month
target_year_index = df_cm.index.get_loc(target_year)
target_month_index = df_cm.columns.get_loc(target_month)

# Add a red border to the target cell
plt.gca().add_patch(patches.Rectangle((target_month_index, target_year_index), 1, 1, fill=False, edgecolor='red', lw=1))

plt.savefig('heatmap.png')
plt.savefig('heatmap.pdf')

# %%
plt.figure(figsize=(17,5))

plt.xlabel('Day')
plt.ylabel('$PM_{10}$ μg/$m^{3}$]')
plt.title("$PM_{10}$  - Αλίαρτος")



x=[]
for i in df['PM10']:
  if i==0:
    x+=[None]
  else:
    x+=[i]



plt.plot(df['DAY'], x, label='$PM_{10}$ 2018-2021')
plt.legend()


plt.xlim(df.loc[1]['DAY'] , df.loc[1460]['DAY'],)
plt.ylim(0,300)

plt.xticks(['1-Jan-18','1-Feb-18','1-Mar-18','1-Apr-18','1-May-18','1-Jun-18','1-Jul-18','1-Aug-18','1-Sep-18','1-Oct-18','1-Nov-18','1-Dec-18','1-Jan-19','1-Feb-19','1-Mar-19','1-Apr-19','1-May-19','1-Jun-19','1-Jul-19','1-Aug-19','1-Sep-19','1-Oct-19','1-Nov-19','1-Dec-19','1-Jan-20','1-Feb-20','1-Mar-20','1-Apr-20','1-May-20','1-Jun-20','1-Jul-20','1-Aug-20','1-Sep-20','1-Oct-20','1-Nov-20','1-Dec-20' , '1-Jan-21', '1-Feb-21','1-Mar-21','1-Apr-21','1-May-21','1-Jun-21','1-Jul-21','1-Aug-21','1-Sep-21','1-Oct-21','1-Nov-21','1-Dec-21' ])
plt.xticks(rotation=90)

plt.axvline(x='22-Mar-18' ,color='g')
plt.axvline(x='4-May-18' ,color='g')

plt.axvline(x='22-Mar-19' ,color='g')
plt.axvline(x='4-May-19' ,color='g')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='g')
plt.axvline(x='4-May-21' ,color='g')


plt.show()

# %%
plt.figure(figsize=(17,5))

plt.xlabel('Day')
plt.ylabel('$PM_{10}$ μg/$m^{3}$]')
plt.title("$PM_{10}$  - Αλίαρτος")



x1=[]
for i in df['NO2']:
  if i==0:
    x1+=[None]
  else:
    x1+=[i]

x2=[]
for j in df['PM25']:
  if j==0:
    x2+=[None]
  else:
    x2+=[j]


plt.plot(df['DAY'], x1, label='$NO_{2}$ 2018-2021')
plt.plot(df['DAY'], x2, label='$PM_{2.5}$ 2018-2021')
plt.legend()


plt.xlim(df.loc[1]['DAY'] , df.loc[1460]['DAY'],)
plt.ylim(0,150)

plt.xticks(['1-Jan-18','1-Feb-18','1-Mar-18','1-Apr-18','1-May-18','1-Jun-18','1-Jul-18','1-Aug-18','1-Sep-18','1-Oct-18','1-Nov-18','1-Dec-18','1-Jan-19','1-Feb-19','1-Mar-19','1-Apr-19','1-May-19','1-Jun-19','1-Jul-19','1-Aug-19','1-Sep-19','1-Oct-19','1-Nov-19','1-Dec-19','1-Jan-20','1-Feb-20','1-Mar-20','1-Apr-20','1-May-20','1-Jun-20','1-Jul-20','1-Aug-20','1-Sep-20','1-Oct-20','1-Nov-20','1-Dec-20' , '1-Jan-21', '1-Feb-21','1-Mar-21','1-Apr-21','1-May-21','1-Jun-21','1-Jul-21','1-Aug-21','1-Sep-21','1-Oct-21','1-Nov-21','1-Dec-21' ])
plt.xticks(rotation=90)

plt.axvline(x='22-Mar-18' ,color='g')
plt.axvline(x='4-May-18' ,color='g')

plt.axvline(x='22-Mar-19' ,color='g')
plt.axvline(x='4-May-19' ,color='g')

plt.axvline(x='22-Mar-20' ,color='r')
plt.axvline(x='4-May-20' ,color='r')

plt.axvline(x='22-Mar-21' ,color='g')
plt.axvline(x='4-May-21' ,color='g')


plt.show()
