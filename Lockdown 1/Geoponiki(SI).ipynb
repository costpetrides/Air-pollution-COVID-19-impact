# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Air-pollution-COVID-19-impact/blob/main/Lockdown%201/Geoponiki(SI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyparsing.helpers import PrecededBy
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Lockdown%201/DATA/GeoponikiLock.csv'
df = pd.read_csv(url)
print(df)
# Out:
#        DAY  COMEAN  COMIN  COMAX  CO20  C021  O3MEAN  O3MIN  O3MAX  O320  ...  \
# 0    1-Mar     0.9    0.5    1.5   0.7   0.4      43     30     53    43  ...
# 1    2-Mar     0.6    0.4    0.8   0.8   0.2      60     47     72    41  ...
# 2    3-Mar     0.6    0.5    0.6   0.7   0.3      51     31     79    58  ...
# 3    4-Mar     0.6    0.4    0.8   0.4   0.6      47     38     59    66  ...
# 4    5-Mar     0.7    0.4    1.1   0.8   0.8      49     38     57    35  ...
# ..     ...     ...    ...    ...   ...   ...     ...    ...    ...   ...  ...
# 87  27-May     0.3    0.2    0.4   0.4   0.3      67     37     85    59  ...
# 88  28-May     0.3    0.2    0.4   0.8   0.0      67     56     79    44  ...
# 89  29-May     0.3    0.2    0.4   0.7   0.0      70     65     79    39  ...
# 90  30-May     0.4    0.3    0.4   0.6   0.0      61     58     63    61  ...
# 91  31-May     0.4    0.4    0.5   0.6   0.0      51     46     57    81  ...
#
#     NOMEAN  NOMIN  NOMAX  NO20  NO21  N02MEAN  NO2MIN  NO2MAX  NO220  N0221
# 0       33      7     68     9    13       42      34      59     41     30
# 1       12      3     23    22     2       35      28      45     45     14
# 2       16      3     27    23     2       35      23      52     28     18
# 3       16     13     18     2    17       40      26      49     24     48
# 4       23      5     41    16    33       38      25      51     43     52
# ..     ...    ...    ...   ...   ...      ...     ...     ...    ...    ...
# 87       6      4     10     1     7       38      18      68     20     49
# 88       7      3     16     8     0       30      13      50     34      0
# 89       3      2      4    17     0       23      11      31     41      0
# 90      12     10     14    10     0       35      30      41     29      0
# 91      13     12     17    15     0       41      36      48     19      0
#
# [92 rows x 21 columns]

# %%
def perc(a,b):
  x=abs(a-b)
  y=(a+b)/2
  return (x/y)*100

# %% [markdown]
# ## **NO**

# %%
plt.figure(figsize=(13,2))

plt.xlabel('Days')
plt.ylabel('$NO \: [μg/m^{3}$]')

plt.plot(df['DAY'], df['NO20'], 'g', label='2020')
plt.plot(df['DAY'], df['NOMEAN'], 'b', label='2016-2019')
plt.fill_between(df['DAY'], df['NOMIN'], df['NOMAX'], alpha=0.2 ,label='min-max (2016-2019)')

plt.legend()

plt.xlim(df.loc[0]['DAY'] , df.loc[91]['DAY'])
plt.ylim(0,70)

plt.axvline(x='4-May' ,color='r')
plt.axvline(x='22-Mar' ,color='r')
plt.xticks(rotation=90)

plt.show()

# %%
Data=np.array(df['NO20'])
Pre=Data[0:23]
Lock=Data[23:66]
Post=Data[66:91]

Data=np.array(df['NOMEAN'])
Pre1=Data[0:23]
Lock1=Data[23:66]
Post1=Data[66:91]

Prev = (np.mean(Pre1),np.mean(Lock1),np.mean(Post1))        # Set of A data
LOCK=   (np.mean(Pre),np.mean(Lock),np.mean(Post))    # Set of B data

names= ['Pre Lockdown', 'Lockdown', 'Post Lockdown']     # Set of names for x asis

fig = plt.figure(figsize=(6,4), dpi=100)
left, bottom, width, height = 0.1, 0.2, 0.8, 0.6
ax = fig.add_axes([left, bottom, width, height])

width = 0.4
ticks = np.arange(len(names))
ax.bar(ticks, Prev, width, label='2016-2019')
ax.bar(ticks + width, LOCK, width, align="center", label='2020', color='green')


ax.set_ylabel('$NO$ $[μg/m^{3}]$')
ax.set_xticks(ticks + width/2)
ax.set_xticklabels(names)

ax.legend(loc='best')
plt.show()

print('2020')
P1=perc(np.mean(Pre), np.mean(Lock))
P2=perc(np.mean(Lock),np.mean(Post))
print('Percentage Difference Pre-Lockdown to Lockdown = %.2f %% ' %(P1))
print('Difference Pre-Lockdown to Lockdown = %.2f  ' %(np.mean(Pre)- np.mean(Lock)))
print('Percentage Difference Lockdown to Post-Lockdown = %.2f %% ' %(P2))
print('Difference Lockdown to Post-Lockdown = %.2f  ' %(np.mean(Lock) -np.mean(Post)))

print()
print('2016-2019')
P11=perc(np.mean(Pre1), np.mean(Lock1))
P22=perc(np.mean(Lock1),np.mean(Post1))
print('Percentage Difference Pre-Lockdown to Lockdown = %.2f %% ' %(P11))
print('Difference Pre-Lockdown to Lockdown = %.2f %% ' %(np.mean(Pre1) - np.mean(Lock1)))
print('Percentage Difference Lockdown to Post-Lockdown = %.2f %% ' %(P22))
print('Difference Lockdown to Post-Lockdown = %.2f %% ' %(np.mean(Lock1) -np.mean(Post1)))
# Out:
# 2020
# Percentage Difference Pre-Lockdown to Lockdown = 98.74 %
# Difference Pre-Lockdown to Lockdown = 8.71
# Percentage Difference Lockdown to Post-Lockdown = 44.76 %
# Difference Lockdown to Post-Lockdown = -2.57
#
# 2016-2019
# Percentage Difference Pre-Lockdown to Lockdown = 33.33 %
# Difference Pre-Lockdown to Lockdown = 3.96 %
# Percentage Difference Lockdown to Post-Lockdown = 31.65 %
# Difference Lockdown to Post-Lockdown = 2.71 %

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Plotting a histogram
plt.figure(figsize=(5,3))

# Define bins from 0 to 1 with increments of 0.1
bins = np.linspace(0, 80, 41, endpoint=True)  # Ensure endpoint is True to include 1.0

# Plotting histograms
plt.hist(df['NO20'][0:23][df['NO20'][0:23]>0], bins=bins, alpha=0.5, label='Pre Lockdown', color= 'red')
plt.hist(df['NO20'][23:66][df['NO20'][23:66]>0], bins=bins, alpha=0.5, label='Lockdown',color= 'green')
plt.hist(df['NO20'][66:91][df['NO20'][66:91]>0], bins=bins, alpha=0.5, label='Post Lockdown',color='orange')


plt.xlabel('$NO \: [μg/m^{3}$]')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.xlim(1,40)  # Ensure x-axis starts at 0 and ends at 1

plt.gca().xaxis.set_minor_locator(plt.MultipleLocator(2))
plt.xticks(np.arange(0, 50, 10))
plt.grid(which='minor', axis='x', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# ## **$NO_{2}$**

# %%
plt.figure(figsize=(13,2))

plt.xlabel('Days')
plt.ylabel('$NO_{2} \: [μg/m^{3}$]')

plt.plot(df['DAY'], df['NO220'], 'g', label='2020')
plt.plot(df['DAY'], df['N02MEAN'], 'b', label='2016-2019')
plt.fill_between(df['DAY'], df['NO2MIN'], df['NO2MAX'], alpha=0.2, label='min-max (2016-2019)')

plt.legend()

plt.xlim(df.loc[0]['DAY'] , df.loc[91]['DAY'])
plt.ylim(0,110)

plt.axvline(x='4-May' ,color='r')
plt.axvline(x='22-Mar' ,color='r')
plt.xticks(rotation=90)

plt.show()

# %%
Data=np.array(df['NO220'])
Pre=Data[0:23]
Lock=Data[23:66]
Post=Data[66:91]

Data=np.array(df['N02MEAN'])
Pre1=Data[0:23]
Lock1=Data[23:66]
Post1=Data[66:91]

Prev = (np.mean(Pre1),np.mean(Lock1),np.mean(Post1))        # Set of A data
LOCK=   (np.mean(Pre),np.mean(Lock),np.mean(Post))    # Set of B data

names= ['Pre Lockdown', 'Lockdown', 'Post Lockdown']     # Set of names for x asis

fig = plt.figure(figsize=(6,4), dpi=100)
left, bottom, width, height = 0.1, 0.2, 0.8, 0.6
ax = fig.add_axes([left, bottom, width, height])

width = 0.4
ticks = np.arange(len(names))
ax.bar(ticks, Prev, width, label='2016-2019')
ax.bar(ticks + width, LOCK, width, align="center", label='2020', color='green')

ax.set_ylabel('$NO_{2}$ $[μg/m^{3}]$')
ax.set_xticks(ticks + width/2)
ax.set_xticklabels(names)

ax.legend(loc='best')
plt.show()

print('2020')
P1=perc(np.mean(Pre), np.mean(Lock))
P2=perc(np.mean(Lock),np.mean(Post))
print('Percentage Difference Pre-Lockdown to Lockdown = %.2f %% ' %(P1))
print('Difference Pre-Lockdown to Lockdown = %.2f  ' %(np.mean(Pre)- np.mean(Lock)))
print('Percentage Difference Lockdown to Post-Lockdown = %.2f %% ' %(P2))
print('Difference Lockdown to Post-Lockdown = %.2f  ' %(np.mean(Lock) -np.mean(Post)))

print()
print('2016-2019')
P11=perc(np.mean(Pre1), np.mean(Lock1))
P22=perc(np.mean(Lock1),np.mean(Post1))
print('Percentage Difference Pre-Lockdown to Lockdown = %.2f %% ' %(P11))
print('Difference Pre-Lockdown to Lockdown = %.2f %% ' %(np.mean(Pre1) - np.mean(Lock1)))
print('Percentage Difference Lockdown to Post-Lockdown = %.2f %% ' %(P22))
print('Difference Lockdown to Post-Lockdown = %.2f %% ' %(np.mean(Lock1) -np.mean(Post1)))
# Out:
# 2020
# Percentage Difference Pre-Lockdown to Lockdown = 51.26 %
# Difference Pre-Lockdown to Lockdown = 13.80
# Percentage Difference Lockdown to Post-Lockdown = 55.17 %
# Difference Lockdown to Post-Lockdown = -15.26
#
# 2016-2019
# Percentage Difference Pre-Lockdown to Lockdown = 3.37 %
# Difference Pre-Lockdown to Lockdown = 1.02 %
# Percentage Difference Lockdown to Post-Lockdown = 0.14 %
# Difference Lockdown to Post-Lockdown = 0.04 %

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Plotting a histogram
plt.figure(figsize=(5,3))

# Define bins from 0 to 1 with increments of 0.1
bins = np.linspace(0, 80, 41, endpoint=True)  # Ensure endpoint is True to include 1.0

# Plotting histograms
plt.hist(df['NO220'][0:23][df['NO220'][0:23]>0], bins=bins, alpha=0.5, label='Pre Lockdown', color= 'red')
plt.hist(df['NO220'][23:66][df['NO220'][23:66]>0], bins=bins, alpha=0.5, label='Lockdown',color= 'green')
plt.hist(df['NO220'][66:91], bins=bins, alpha=0.5, label='Post Lockdown',color='orange')

plt.xlabel('$NO_{2} \: [μg/m^{3}$]')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.xlim(1,80)  # Ensure x-axis starts at 0 and ends at 1


plt.gca().xaxis.set_minor_locator(plt.MultipleLocator(2))
plt.xticks(np.arange(0, 80, 10))
plt.grid(which='minor', axis='x', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# ## $O_{3}$

# %%
plt.figure(figsize=(13,2))

plt.xlabel('Days')
plt.ylabel('$O_{3} \:  [μg/m^{3}$]')

x=[]
for i in df['O320']:
  if i==0:
    x+=[None]
  else:
    x+=[i]

plt.plot(df['DAY'], x, 'g', label='2020')
plt.plot(df['DAY'], df['O3MEAN'], 'b', label='2016-2019')
plt.fill_between(df['DAY'], df['O3MIN'], df['O3MAX'], alpha=0.2,label='min-max (2016-2019)')

plt.legend()

plt.xlim(df.loc[0]['DAY'] , df.loc[91]['DAY'])
plt.ylim(0,150)

plt.axvline(x='4-May' ,color='r')
plt.axvline(x='22-Mar' ,color='r')
plt.xticks(rotation=90)

plt.show()

# %%
Data=np.array(df['O320'])
Pre=Data[0:23]
Lock=Data[23:66]
Post=Data[66:91]

Postnew=[]
for c in Post:
  if c!=0:
    Postnew+=[c]

Data=np.array(df['O3MEAN'])
Pre1=Data[0:23]
Lock1=Data[23:66]
Post1=Data[66:91]

Prev = (np.mean(Pre1),np.mean(Lock1),np.mean(Post1))        # Set of A data
LOCK=   (np.mean(Pre),np.mean(Lock),np.mean(Postnew))    # Set of B data

names= ['Pre Lockdown', 'Lockdown', 'Post Lockdown']     # Set of names for x asis

fig = plt.figure(figsize=(6,4), dpi=100)
left, bottom, width, height = 0.1, 0.2, 0.8, 0.6
ax = fig.add_axes([left, bottom, width, height])

width = 0.4
ticks = np.arange(len(names))
ax.bar(ticks, Prev, width, label='2016-2019')
ax.bar(ticks + width, LOCK, width, align="center", label='2020', color='green')

ax.set_ylabel('$O_{3}$ $[μg/m^{3}]$')
ax.set_xticks(ticks + width/2)
ax.set_xticklabels(names)

ax.legend(loc='best')
plt.show()

print('2020')
P1=perc(np.mean(Pre), np.mean(Lock))
P2=perc(np.mean(Lock),np.mean(Post))
print('Percentage Difference Pre-Lockdown to Lockdown = %.2f %% ' %(P1))
print('Difference Pre-Lockdown to Lockdown = %.2f  ' %(np.mean(Pre)- np.mean(Lock)))
print('Percentage Difference Lockdown to Post-Lockdown = %.2f %% ' %(P2))
print('Difference Lockdown to Post-Lockdown = %.2f  ' %(np.mean(Lock) -np.mean(Post)))

print()
print('2016-2019')
P11=perc(np.mean(Pre1), np.mean(Lock1))
P22=perc(np.mean(Lock1),np.mean(Post1))
print('Percentage Difference Pre-Lockdown to Lockdown = %.2f %% ' %(P11))
print('Difference Pre-Lockdown to Lockdown = %.2f %% ' %(np.mean(Pre1) - np.mean(Lock1)))
print('Percentage Difference Lockdown to Post-Lockdown = %.2f %% ' %(P22))
print('Difference Lockdown to Post-Lockdown = %.2f %% ' %(np.mean(Lock1) -np.mean(Post1)))
# Out:
# 2020
# Percentage Difference Pre-Lockdown to Lockdown = 27.29 %
# Difference Pre-Lockdown to Lockdown = -16.44
# Percentage Difference Lockdown to Post-Lockdown = 3.04 %
# Difference Lockdown to Post-Lockdown = 2.05
#
# 2016-2019
# Percentage Difference Pre-Lockdown to Lockdown = 14.43 %
# Difference Pre-Lockdown to Lockdown = -8.64 %
# Percentage Difference Lockdown to Post-Lockdown = 6.51 %
# Difference Lockdown to Post-Lockdown = 4.05 %

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Plotting a histogram
plt.figure(figsize=(5,3))

# Define bins from 0 to 1 with increments of 0.1
bins = np.linspace(0, 200, 101, endpoint=True)  # Ensure endpoint is True to include 1.0

# Plotting histograms
plt.hist(df['O320'][0:23], bins=bins, alpha=0.5, label='Pre Lockdown', color= 'red')
plt.hist(df['O320'][23:66], bins=bins, alpha=0.5, label='Lockdown',color= 'green')
plt.hist(df['O320'][66:91], bins=bins, alpha=0.5, label='Post Lockdown',color='orange')

plt.xlabel('$O_{3} \: [μg/m^{3}$]')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.xlim(20,100)  # Ensure x-axis starts at 0 and ends at 1


plt.gca().xaxis.set_minor_locator(plt.MultipleLocator(2))
plt.xticks(np.arange(20, 120, 20))
plt.grid(which='minor', axis='x', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# # CO

# %%
plt.figure(figsize=(13,2))

plt.xlabel('Days')
plt.ylabel('$CO \: [mg/m^{3}$]')

plt.plot(df['DAY'], df['CO20'], 'g', label='2020')
plt.plot(df['DAY'], df['COMEAN'], 'b', label='2016-2019')
plt.fill_between(df['DAY'], df['COMIN'], df['COMAX'], alpha=0.2 ,label='min-max (2016-2019)')
plt.legend()

plt.xlim(df.loc[0]['DAY'] , df.loc[91]['DAY'])
plt.ylim(0,2)

plt.axvline(x='4-May' ,color='r')
plt.axvline(x='22-Mar' ,color='r')
plt.xticks(rotation=90)

plt.show()

# %%
Data=np.array(df['CO20'])
Pre=Data[0:23]
Lock=Data[23:66]
Post=Data[66:91]

Data=np.array(df['COMEAN'])
Pre1=Data[0:23]
Lock1=Data[23:66]
Post1=Data[66:91]

Prev = (np.mean(Pre1),np.mean(Lock1),np.mean(Post1))        # Set of A data
LOCK=   (np.mean(Pre),np.mean(Lock),np.mean(Post))    # Set of B data

names= ['Pre Lockdown', 'Lockdown', 'Post Lockdown']     # Set of names for x asis

fig = plt.figure(figsize=(6,4), dpi=100)
left, bottom, width, height = 0.1, 0.2, 0.8, 0.6
ax = fig.add_axes([left, bottom, width, height])

width = 0.4
ticks = np.arange(len(names))
ax.bar(ticks, Prev, width, label='2016-2019')
ax.bar(ticks + width, LOCK, width, align="center", label='2020', color='green')

ax.set_ylabel('$CO}$ $[mg/m^{3}]$')
ax.set_xticks(ticks + width/2)
ax.set_xticklabels(names)

ax.legend(loc='best')
plt.show()

print('2020')
P1=perc(np.mean(Pre), np.mean(Lock))
P2=perc(np.mean(Lock),np.mean(Post))
print('Percentage Difference Pre-Lockdown to Lockdown = %.2f %% ' %(P1))
print('Difference Pre-Lockdown to Lockdown = %.2f  ' %(np.mean(Pre)- np.mean(Lock)))
print('Percentage Difference Lockdown to Post-Lockdown = %.2f %% ' %(P2))
print('Difference Lockdown to Post-Lockdown = %.2f  ' %(np.mean(Lock) -np.mean(Post)))

print()
print('2016-2019')
P11=perc(np.mean(Pre1), np.mean(Lock1))
P22=perc(np.mean(Lock1),np.mean(Post1))
print('Percentage Difference Pre-Lockdown to Lockdown = %.2f %% ' %(P11))
print('Difference Pre-Lockdown to Lockdown = %.2f %% ' %(np.mean(Pre1) - np.mean(Lock1)))
print('Percentage Difference Lockdown to Post-Lockdown = %.2f %% ' %(P22))
print('Difference Lockdown to Post-Lockdown = %.2f %% ' %(np.mean(Lock1) -np.mean(Post1)))
# Out:
# 2020
# Percentage Difference Pre-Lockdown to Lockdown = 37.82 %
# Difference Pre-Lockdown to Lockdown = 0.22
# Percentage Difference Lockdown to Post-Lockdown = 6.84 %
# Difference Lockdown to Post-Lockdown = -0.03
#
# 2016-2019
# Percentage Difference Pre-Lockdown to Lockdown = 15.54 %
# Difference Pre-Lockdown to Lockdown = 0.08 %
# Percentage Difference Lockdown to Post-Lockdown = 27.17 %
# Difference Lockdown to Post-Lockdown = 0.12 %

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Plotting a histogram
plt.figure(figsize=(5,3))

# Define bins from 0 to 1 with increments of 0.1
bins = np.linspace(0, 1.5, 16, endpoint=True)  # Ensure endpoint is True to include 1.0

# Plotting histograms
plt.hist(df['CO20'][0:23], bins=bins, alpha=0.5, label='Pre Lockdown', color= 'red')
plt.hist(df['CO20'][23:66][df['CO20'][23:66]>0], bins=bins, alpha=0.5, label='Lockdown',color= 'green')
plt.hist(df['CO20'][66:91], bins=bins, alpha=0.5, label='Post Lockdown',color='orange')

plt.xlabel('$CO \: [mg/m^{3}$]')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.xlim(0,1.5)  # Ensure x-axis starts at 0 and ends at 1

plt.gca().xaxis.set_minor_locator(plt.MultipleLocator(0.1))
plt.xticks(np.arange(0, 2, 0.5))
plt.grid(which='minor', axis='x', linestyle='--', linewidth=0.5)
plt.show()
