# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Air-pollution-COVID-19-impact/blob/main/Correlation/PAT-Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Patision

# %%
import scipy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyparsing.helpers import PrecededBy
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Lockdown%201/DATA/PatisionLock.csv'
df = pd.read_csv(url)
print(df)
# Out:
#        DAY  SO2MEAN  SO2MIN  SO2MAX  SO220  SO221  COMEAN  COMIN  COMAX  CO20  \
# 0    1-Mar      5.3     3.2     7.9   18.6    2.5     1.6    1.3    1.8   1.1
# 1    2-Mar      5.6     4.6     6.4   20.3    2.1     1.2    0.8    1.6   1.1
# 2    3-Mar      7.5     3.3    14.1   16.3    2.7     1.7    1.5    2.0   0.7
# 3    4-Mar      8.1     5.6    15.0   18.1    8.3     1.4    1.2    1.5   0.7
# 4    5-Mar      7.5     5.5     9.8   19.7    6.0     1.2    1.0    1.3   1.0
# ..     ...      ...     ...     ...    ...    ...     ...    ...    ...   ...
# 87  27-May      6.4     2.3     9.3    2.2    8.8     0.8    0.2    1.4   0.9
# 88  28-May      6.0     2.3     8.6    3.0    9.0     0.7    0.3    1.3   1.1
# 89  29-May      5.7     2.5     8.1    4.6    7.4     0.7    0.4    1.3   1.3
# 90  30-May      5.8     2.8     8.1    4.4    7.6     1.3    0.7    1.7   1.0
# 91  31-May      5.9     3.3     9.0    4.8    8.6     1.4    0.6    1.9   0.8
#
#     ...  N02MEAN  NO2MIN  NO2MAX  NO220  NO221  BENMEAN  BENMIN  BENMAX  \
# 0   ...     87.3    84.8    89.9   89.1   61.6      6.3     3.2     8.6
# 1   ...     80.5    66.4    88.5   86.8   45.5      4.6     3.1     5.7
# 2   ...     77.8    50.4   102.5   67.0   62.2      7.4     4.9    10.0
# 3   ...     81.4    77.2    90.0   60.7   97.2      5.9     4.4     6.7
# 4   ...     78.0    47.2    93.0   82.0   93.5      6.1     4.0     8.9
# ..  ...      ...     ...     ...    ...    ...      ...     ...     ...
# 87  ...     78.1    41.3    97.2   73.3  108.3      4.7     3.9     5.4
# 88  ...     74.9    37.5   101.8   79.7   92.3      3.6     2.1     5.1
# 89  ...     72.6    50.9    93.5   84.4   81.3      2.9     1.9     4.6
# 90  ...     92.6    65.8   110.8   82.2   80.1      6.1     3.6     7.3
# 91  ...     94.2    65.8   113.3   78.8   85.4      6.1     3.4     8.2
#
#     BEN20  BEN21
# 0     3.6    1.8
# 1     4.0    1.1
# 2     3.7    1.4
# 3     2.3    7.7
# 4     3.4    4.7
# ..    ...    ...
# 87    2.9    3.3
# 88    3.4    2.8
# 89    4.1    2.0
# 90    3.4    2.3
# 91    2.4    2.5
#
# [92 rows x 31 columns]

# %% [markdown]
# # $NO_{2}$

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

# Plotting
plt.figure(figsize=(5, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$NO_{2}$ $[μg/m^{3}]$')

# Filter zero values
x = df['O320'].values[:23]
y = df['NO220'].values[:23]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask], label='2020')

# Calculate Pearson correlation coefficient
r = stats.pearsonr(x[mask], y[mask])[0]

# Linear regression line
m, b = np.polyfit(x[mask], y[mask], 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 160, 20))
plt.yticks(np.arange(0, 160, 20))

# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.minorticks_on()
plt.gca().set_xticks(np.arange(0, 140, 10), minor=True)
plt.gca().set_yticks(np.arange(0, 140, 10), minor=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

# Plotting
plt.figure(figsize=(5, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$NO_{2}$ $[μg/m^{3}]$')

# Filter zero values
x = df['O320'].values[23:66]
y = df['NO220'].values[23:66]
mask = (x != 0) & (y != 0)


# Calculate Pearson correlation coefficient
r = stats.pearsonr(x[mask], y[mask])[0]

plt.scatter(x[mask], y[mask], label='2020')

# Linear regression line
m, b = np.polyfit(x[mask], y[mask], 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 160, 20))
plt.yticks(np.arange(0, 160, 20))

# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.minorticks_on()
plt.gca().set_xticks(np.arange(0, 140, 10), minor=True)
plt.gca().set_yticks(np.arange(0, 140, 10), minor=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd


# Plotting
plt.figure(figsize=(5, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$NO_{2}$ $[μg/m^{3}]$')

# Filter zero values
x = df['O320'].values[66:91]
y = df['NO220'].values[66:91]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask], label='2020')

# Calculate Pearson correlation coefficient
r = stats.pearsonr(x[mask], y[mask])[0]

# Linear regression line
m, b = np.polyfit(x[mask], y[mask], 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 160, 20))
plt.yticks(np.arange(0, 160, 20))

# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.minorticks_on()
plt.gca().set_xticks(np.arange(0, 140, 10), minor=True)
plt.gca().set_yticks(np.arange(0, 140, 10), minor=True)
plt.show()

# %% [markdown]
# # $NO$

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd


# Plotting
plt.figure(figsize=(5, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$NO$ $[μg/m^{3}]$')

# Filter zero values
x = df['O320'].values[:23]
y = df['NO20'].values[:23]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask], label='2020')

# Calculate Pearson correlation coefficient
r = stats.pearsonr(x[mask], y[mask])[0]

# Linear regression line
m, b = np.polyfit(x[mask], y[mask], 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 180, 20))
plt.yticks(np.arange(0, 180, 20))
plt.xlim(0, 160)
plt.ylim(0, 160)


# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.minorticks_on()
plt.gca().set_xticks(np.arange(0, 160, 10), minor=True)
plt.gca().set_yticks(np.arange(0, 160, 10), minor=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd


# Plotting
plt.figure(figsize=(5, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$NO$ $[μg/m^{3}]$')

# Filter zero values
x = df['O320'].values[23:66]
y = df['NO20'].values[23:66]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask], label='2020')

# Calculate Pearson correlation coefficient
r = stats.pearsonr(x[mask], y[mask])[0]

# Linear regression line
m, b = np.polyfit(x[mask], y[mask], 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 180, 20))
plt.yticks(np.arange(0, 180, 20))
plt.xlim(0, 160)
plt.ylim(0, 160)

# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.minorticks_on()
plt.gca().set_xticks(np.arange(0, 160, 10), minor=True)
plt.gca().set_yticks(np.arange(0, 160, 10), minor=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd


# Plotting
plt.figure(figsize=(5, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$NO$ $[μg/m^{3}]$')

# Filter zero values
x = df['O320'].values[66:91]
y = df['NO20'].values[66:91]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask], label='2020')

# Calculate Pearson correlation coefficient
r = stats.pearsonr(x[mask], y[mask])[0]

# Linear regression line
m, b = np.polyfit(x[mask], y[mask], 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 180, 20))
plt.yticks(np.arange(0, 180, 20))
plt.xlim(0, 160)
plt.ylim(0, 160)

# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.minorticks_on()
plt.gca().set_xticks(np.arange(0, 160, 10), minor=True)
plt.gca().set_yticks(np.arange(0, 160, 10), minor=True)
plt.show()

# %% [markdown]
# # CO

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

# Plotting
plt.figure(figsize=(3, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$CO  \, mg/m^{3}]$')  # Adjusted y-axis label

# Filter zero values
x = df['O320'].values[0:23]
y = df['CO20'].values[0:23]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask]*100, label='2020')

# Calculate Pearson correlation coefficient
r = stats.pearsonr(x[mask], y[mask])[0]

# Linear regression line
m, b = np.polyfit(x[mask], y[mask]*100, 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 180, 20))
plt.yticks(np.arange(0, 180, 20))


plt.gca().set_aspect('auto', adjustable='box')
plt.annotate('$\\times 10^{-2}$', xy=(-0.07, 1), xycoords='axes fraction',
             fontsize=10, ha='right', va='bottom')


# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.minorticks_on()
plt.gca().set_xticks(np.arange(0, 160, 10), minor=True)
plt.gca().set_yticks(np.arange(0, 160, 10), minor=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

# Plotting
plt.figure(figsize=(3, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$CO  \, mg/m^{3}]$')  # Adjusted y-axis label

# Filter zero values
x = df['O320'].values[23:66]
y = df['CO20'].values[23:66]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask]*100, label='2020')

# Calculate Pearson correlation coefficient
r = stats.pearsonr(x[mask], y[mask])[0]

# Linear regression line
m, b = np.polyfit(x[mask], y[mask]*100, 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 180, 20))
plt.yticks(np.arange(0, 180, 20))


plt.gca().set_aspect('auto', adjustable='box')
plt.annotate('$\\times 10^{-2}$', xy=(-0.07, 1), xycoords='axes fraction',
             fontsize=10, ha='right', va='bottom')


# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.minorticks_on()
plt.gca().set_xticks(np.arange(0, 160, 10), minor=True)
plt.gca().set_yticks(np.arange(0, 160, 10), minor=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

# Plotting
plt.figure(figsize=(3, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$CO  \, mg/m^{3}]$')  # Adjusted y-axis label

# Filter zero values
x = df['O320'].values[66:91]
y = df['CO20'].values[66:91]
mask = (x != 0) & (y != 0) & (y <= 160)

plt.scatter(x[mask], y[mask]*100, label='2020')

# Calculate Pearson correlation coefficient
r = stats.pearsonr(x[mask], y[mask])[0]

# Linear regression line
m, b = np.polyfit(x[mask], y[mask]*100, 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 180, 20))
plt.yticks(np.arange(0, 180, 20))
plt.xlim(0, 160)
plt.ylim(0, 160)

plt.gca().set_aspect('auto', adjustable='box')
plt.annotate('$\\times 10^{-2}$', xy=(-0.07, 1), xycoords='axes fraction',
             fontsize=10, ha='right', va='bottom')


# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.minorticks_on()
plt.gca().set_xticks(np.arange(0, 160, 10), minor=True)
plt.gca().set_yticks(np.arange(0, 160, 10), minor=True)
plt.show()

# %% [markdown]
# # $C_{6}H_{6}$

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd


# Plotting
plt.figure(figsize=(3, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$C_{6}H_{6}$ $[μg/m^{3}]$')

# Filter zero values
x = df['O320'].values[:23]
y = df['BEN20'].values[:23]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask]*10, label='2020')

# Calculate Pearson correlation coefficient
r = stats.pearsonr(x[mask], y[mask])[0]

# Linear regression line
m, b = np.polyfit(x[mask], y[mask]*10, 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 120, 20))
plt.yticks(np.arange(0, 120, 20))
plt.xlim(0, 100)
plt.ylim(0, 100)

# Set equal scaling
plt.gca().set_aspect('auto', adjustable='box')
plt.annotate('$\\times 10^{-1}$', xy=(-0.07, 1), xycoords='axes fraction',
             fontsize=10, ha='right', va='bottom')

# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.minorticks_on()
plt.gca().set_xticks(np.arange(0, 100, 10), minor=True)
plt.gca().set_yticks(np.arange(0, 100, 10), minor=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

# Plotting
plt.figure(figsize=(3, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$C_{6}H_{6}$ $[μg/m^{3}]$')

# Filter zero values
x = df['O320'].values[23:66]
y = df['BEN20'].values[23:66]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask]*10, label='2020')

# Calculate Pearson correlation coefficient
r = stats.pearsonr(x[mask], y[mask])[0]

# Linear regression line
m, b = np.polyfit(x[mask], y[mask]*10, 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 120, 20))
plt.yticks(np.arange(0, 120, 20))
plt.xlim(0, 100)
plt.ylim(0, 100)

# Set equal scaling
plt.gca().set_aspect('auto', adjustable='box')
plt.annotate('$\\times 10^{-1}$', xy=(-0.07, 1), xycoords='axes fraction',
             fontsize=10, ha='right', va='bottom')

# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.minorticks_on()
plt.gca().set_xticks(np.arange(0, 100, 10), minor=True)
plt.gca().set_yticks(np.arange(0, 100, 10), minor=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

# Plotting
plt.figure(figsize=(3, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$C_{6}H_{6}$ $[μg/m^{3}]$')

# Filter zero values
x = df['O320'].values[66:91]
y = df['BEN20'].values[66:91]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask]*10, label='2020')

# Calculate Pearson correlation coefficient
r = stats.pearsonr(x[mask], y[mask])[0]

# Linear regression line
m, b = np.polyfit(x[mask], y[mask]*10, 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 120, 20))
plt.yticks(np.arange(0, 120, 20))
plt.xlim(0, 100)
plt.ylim(0, 100)

# Set equal scaling
plt.gca().set_aspect('auto', adjustable='box')
plt.annotate('$\\times 10^{-1}$', xy=(-0.07, 1), xycoords='axes fraction',
             fontsize=10, ha='right', va='bottom')

# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.minorticks_on()
plt.gca().set_xticks(np.arange(0, 100, 10), minor=True)
plt.gca().set_yticks(np.arange(0, 100, 10), minor=True)
plt.show()
