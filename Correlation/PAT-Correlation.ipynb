# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Air-pollution-COVID-19-impact/blob/main/Correlation/PAT-Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Patision

# %%
import scipy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyparsing.helpers import PrecededBy
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Lockdown%201/DATA/PatisionLock.csv'
df = pd.read_csv(url)
print(df)
# Out:
#        DAY  SO2MEAN  SO2MIN  SO2MAX  SO220  SO221  COMEAN  COMIN  COMAX  CO20  \
# 0    1-Mar      5.3     3.2     7.9   18.6    2.5     1.6    1.3    1.8   1.1
# 1    2-Mar      5.6     4.6     6.4   20.3    2.1     1.2    0.8    1.6   1.1
# 2    3-Mar      7.5     3.3    14.1   16.3    2.7     1.7    1.5    2.0   0.7
# 3    4-Mar      8.1     5.6    15.0   18.1    8.3     1.4    1.2    1.5   0.7
# 4    5-Mar      7.5     5.5     9.8   19.7    6.0     1.2    1.0    1.3   1.0
# ..     ...      ...     ...     ...    ...    ...     ...    ...    ...   ...
# 87  27-May      6.4     2.3     9.3    2.2    8.8     0.8    0.2    1.4   0.9
# 88  28-May      6.0     2.3     8.6    3.0    9.0     0.7    0.3    1.3   1.1
# 89  29-May      5.7     2.5     8.1    4.6    7.4     0.7    0.4    1.3   1.3
# 90  30-May      5.8     2.8     8.1    4.4    7.6     1.3    0.7    1.7   1.0
# 91  31-May      5.9     3.3     9.0    4.8    8.6     1.4    0.6    1.9   0.8
#
# ...

# %% [markdown]
# # $NO_{2}$

# %%
r=scipy.stats.pearsonr(df['NO220'][0:23],df['O320'][0:23])[0]

plt.figure(figsize=(5,3))
plt.xlabel('$NO_{2} \: [μg/m^{3}]$')
plt.ylabel('$O_{3} \: [μg/m^{3}]$')

plt.title("$NO_{2}$ - Pre Lockdown")

x=[]
for i in df['NO220'][0:23]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O320'][0:23]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.scatter(x, y, label='2020')
plt.legend()

m, b = np.polyfit(df['NO220'][0:23], df['O320'][0:23], 1)

xx=np.linspace(30,100,1000)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()

# %%
r=scipy.stats.pearsonr(df['NO220'][23:66],df['O320'][23:66])[0]

plt.figure(figsize=(5,3))
plt.xlabel('$NO_{2} \: [μg/m^{3}]$')
plt.ylabel('$O_{3} \: [μg/m^{3}]$')

plt.title("$NO_{2}$ - Lockdown")

x=[]
for i in df['NO220'][23:66]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O320'][23:66]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.scatter(x, y, label='2020')
plt.legend()

m, b = np.polyfit(df['NO220'][23:66], df['O320'][23:66], 1)

xx=np.linspace(10,90,9000)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()

# %%
r=scipy.stats.pearsonr(df['NO220'][66:91],df['O320'][66:91])[0]

plt.figure(figsize=(5,3))
plt.xlabel('$NO_{2} \: [μg/m^{3}]$')
plt.ylabel('$O_{3} \: [μg/m^{3}]$')

plt.title("$NO_{2}$ - Post Lockdown")

x=[]
for i in df['NO220'][66:91]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O320'][66:91]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.scatter(x, y, label='2020')
plt.legend()

m, b = np.polyfit(df['NO220'][66:91], df['O320'][66:91], 1)

xx=np.linspace(20,130,13000)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()

# %% [markdown]
# # $NO$

# %%
r=scipy.stats.pearsonr(df['NO20'][0:23],df['O320'][0:23])[0]

plt.figure(figsize=(5,3))
plt.xlabel('$NO \: [μg/m^{3}]$')
plt.ylabel('$O_{3} \: [μg/m^{3}]$')

plt.title("$NO$ - Pre Lockdown")

x=[]
for i in df['NO20'][0:23]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O320'][0:23]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.scatter(x, y, label='2020')
plt.legend()

m, b = np.polyfit(df['NO20'][0:23], df['O320'][0:23], 1)

xx=np.linspace(5,120,1000)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()

# %%
r=scipy.stats.pearsonr(df['NO20'][23:66],df['O320'][23:66])[0]

plt.figure(figsize=(5,3))
plt.xlabel('$NO \: [μg/m^{3}]$')
plt.ylabel('$O_{3} \: [μg/m^{3}]$')

plt.title("$NO$ - Lockdown")

x=[]
for i in df['NO20'][23:66]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O320'][23:66]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.scatter(x, y, label='2020')
plt.legend()

m, b = np.polyfit(df['NO20'][23:66], df['O320'][23:66], 1)

xx=np.linspace(0,55,1000)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()

# %%
r=scipy.stats.pearsonr(df['NO20'][66:91],df['O320'][66:91])[0]

plt.figure(figsize=(5,3))
plt.xlabel('$NO \: [μg/m^{3}]$')
plt.ylabel('$O_{3} \: [μg/m^{3}]$')

plt.title("$NO$ - Post Lockdown")

x=[]
for i in df['NO20'][66:91]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O320'][66:91]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.scatter(x, y, label='2020')
plt.legend()

m, b = np.polyfit(df['NO20'][66:91], df['O320'][66:91], 1)

xx=np.linspace(0,145,1000)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()

# %% [markdown]
# # CO

# %%
r=scipy.stats.pearsonr(df['CO20'][0:23],df['O320'][0:23])[0]

plt.figure(figsize=(5,3))
plt.xlabel('$CO \: [mg/m^{3}]$')
plt.ylabel('$O_{3} \: [μg/m^{3}]$')

plt.title("$CO$ - Pre Lockdown")

x=[]
for i in df['CO20'][0:23]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O320'][0:23]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.scatter(x, y, label='2020')
plt.legend()

m, b = np.polyfit(df['CO20'][0:23], df['O320'][0:23], 1)

xx=np.linspace(0,1.7,1000)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()

# %%
r=scipy.stats.pearsonr(df['CO20'][23:66],df['O320'][23:66])[0]

plt.figure(figsize=(5,3))
plt.xlabel('$CO \: [mg/m^{3}]$')
plt.ylabel('$O_{3} \: [μg/m^{3}]$')

plt.title("$CO$ - Lockdown")

x=[]
for i in df['CO20'][23:66]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O320'][23:66]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.scatter(x, y, label='2020')
plt.legend()

m, b = np.polyfit(df['CO20'][23:66], df['O320'][23:66], 1)

xx=np.linspace(0,0.8,100)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()

# %%
r=scipy.stats.pearsonr(df['CO20'][66:91],df['O320'][66:91])[0]

plt.figure(figsize=(5,3))
plt.xlabel('$CO \: [mg/m^{3}]$')
plt.ylabel('$O_{3} \: [μg/m^{3}]$')

plt.title("$CO$ - Post Lockdown")

x=[]
for i in df['CO20'][66:91]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O320'][66:91]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.scatter(x, y, label='2020')
plt.legend()

m, b = np.polyfit(df['CO20'][66:91], df['O320'][66:91], 1)

xx=np.linspace(0,2,100)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()

# %% [markdown]
# # $C_{6}H_{6}$

# %%
r=scipy.stats.pearsonr(df['NO220'][0:23],df['O320'][0:23])[0]

plt.figure(figsize=(5,3))
plt.xlabel('$C_{6}H_{6} \: [μg/m^{3}]$')
plt.ylabel('$O_{3} \: [μg/m^{3}]$')

plt.title("$C_{6}H_{6}$ - Pre Lockdown")

x=[]
for i in df['BEN20'][0:23]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O320'][0:23]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.scatter(x, y, label='2020')
plt.legend()

m, b = np.polyfit(df['BEN20'][0:23], df['O320'][0:23], 1)

xx=np.linspace(0,6,10)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()

# %%
r=scipy.stats.pearsonr(df['BEN20'][23:66],df['O320'][23:66])[0]

plt.figure(figsize=(5,3))
plt.xlabel('$C_{6}H_{6} \: [μg/m^{3}]$')
plt.ylabel('$O_{3} \: [μg/m^{3}]$')

plt.title("$C_{6}H_{6}$ - Lockdown")

x=[]
for i in df['BEN20'][23:66]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O320'][23:66]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.scatter(x, y, label='2020')
plt.legend()

m, b = np.polyfit(df['BEN20'][23:66], df['O320'][23:66], 1)

xx=np.linspace(0,3,3)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()

# %%
r=scipy.stats.pearsonr(df['BEN20'][66:91],df['O320'][66:91])[0]

plt.figure(figsize=(5,3))
plt.xlabel('$C_{6}H_{6} \: [μg/m^{3}]$')
plt.ylabel('$O_{3} \: [μg/m^{3}]$')

plt.title("$C_{6}H_{6}$ - Post Lockdown")

x=[]
for i in df['BEN20'][66:91]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O320'][66:91]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.scatter(x, y, label='2020')
plt.legend()

m, b = np.polyfit(df['BEN20'][66:91], df['O320'][66:91], 1)

xx=np.linspace(0,12,2)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()
