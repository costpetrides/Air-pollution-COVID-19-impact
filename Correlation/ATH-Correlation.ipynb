# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Air-pollution-COVID-19-impact/blob/main/Correlation/ATH-Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Athinas

# %%
import scipy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pyparsing.helpers import PrecededBy
url='https://raw.githubusercontent.com/costpetrides/Air-pollution-COVID-19-impact/main/Lockdown%201/DATA/AthinasLock.csv'
df = pd.read_csv(url)
print(df)
# Out:
#        DAY  CO20  C021  COMEAN  COMIN  COMAX  NO20  NO21  NOMEAN  NOMIN  ...  \
# 0    1-Mar   0.6   0.4     0.6    0.5    0.9    39    32      39     21  ...
# 1    2-Mar   0.5   0.4     0.5    0.4    0.6    25    27      25     25  ...
# 2    3-Mar   0.4   0.5     0.5    0.3    0.6    23    24      23     21  ...
# 3    4-Mar   0.3   0.7     0.5    0.2    0.7    10    21      28     13  ...
# 4    5-Mar   0.5   0.7     0.6    0.4    0.9    23    11      36     17  ...
# ..     ...   ...   ...     ...    ...    ...   ...   ...     ...    ...  ...
# 87  27-May   0.3   0.1     0.5    0.3    0.6     7    13      24     13  ...
# 88  28-May   0.4   0.1     0.5    0.3    0.7    11    12      23     17  ...
# 89  29-May   0.5   0.1     0.4    0.3    0.6    18    14      20     16  ...
# 90  30-May   0.5   0.1     0.4    0.3    0.5    17    10      21     14  ...
# 91  31-May   0.3   0.1     0.5    0.4    0.6    10    18      30     16  ...
#
#     O320  O321  O3MEAN  03MIN  03MAX  SO220  SO221  SO2MEAN  SO2MIN  SO2MAX
# 0     29    27      28      2     39      4      0        5       3       8
# 1     28    30      44     38     54      3      0        3       2       5
# 2     39    20      40     35     46      3      0        5       2      10
# 3     42    21      38     28     50      2      0        5       3      10
# 4     22    21      32     19     45      4      0        5       3       6
# ..   ...   ...     ...    ...    ...    ...    ...      ...     ...     ...
# 87    27    70      54     14     70      2      0        4       2       7
# 88    24    71      49     18     66      2      0        4       2       6
# 89    14    79      51     21     67      2      0        4       3       5
# 90    31    69      51     20     70      3      0        4       3       5
# 91    32    74      39     16     67      2      0        5       3       6
#
# [92 rows x 26 columns]

# %% [markdown]
# # $NO_{2}$

# %%
plt.figure(figsize=(13,2))

plt.xlabel('Days')
plt.ylabel('$NO_{2}$ / $O_{3}$   $[μg/m^{3}]$')

plt.plot(df['DAY'], df['NO220'], 'b', label='2020 $NO_{2}$')
plt.plot(df['DAY'], df['O320'], 'g', label='2020 $O_{3}$')

plt.legend()

plt.xlim(df.loc[0]['DAY'] , df.loc[91]['DAY'])
plt.ylim(0,150)

plt.axvline(x='4-May' ,color='r')
plt.axvline(x='22-Mar' ,color='r')
plt.xticks(rotation=90)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

# Assuming df is your DataFrame

# Calculate Pearson correlation coefficient
r = stats.pearsonr(df['O320'].values[:23], df['NO220'].values[:23])[0]

# Plotting
plt.figure(figsize=(5, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$NO_{2}$ $[μg/m^{3}]$')

# Filter zero values
x = df['O320'].values[:23]
y = df['NO220'].values[:23]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask], label='2020')

# Linear regression line
m, b = np.polyfit(x[mask], y[mask], 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 70, 10))
plt.yticks(np.arange(0, 70, 10))
plt.grid(True)

# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

# Assuming df is your DataFrame

# Calculate Pearson correlation coefficient
r = stats.pearsonr(df['O320'].values[23:66], df['NO220'].values[23:66])[0]

# Plotting
plt.figure(figsize=(5, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$NO_{2}$ $[μg/m^{3}]$')

# Filter zero values
x = df['O320'].values[23:66]
y = df['NO220'].values[23:66]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask], label='2020')

# Linear regression line
m, b = np.polyfit(x[mask], y[mask], 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 70, 10))
plt.yticks(np.arange(0, 70, 10))
plt.grid(True)

# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

# Assuming df is your DataFrame

# Calculate Pearson correlation coefficient
r = stats.pearsonr(df['O320'].values[66:91], df['NO220'].values[66:91])[0]

# Plotting
plt.figure(figsize=(5, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$NO_{2}$ $[μg/m^{3}]$')

# Filter zero values
x = df['O320'].values[66:91]
y = df['NO220'].values[66:91]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask], label='2020')

# Linear regression line
m, b = np.polyfit(x[mask], y[mask], 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 70, 10))
plt.yticks(np.arange(0, 70, 10))
plt.grid(True)

# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %% [markdown]
# #NO

# %%
plt.figure(figsize=(13,2))

plt.xlabel('Days')
plt.ylabel('$NO$ / $O_{3}$ $[μg/m^{3}]$')

plt.plot(df['DAY'], df['NO20'], 'b', label='2020 $NO$')
plt.plot(df['DAY'], df['O320'], 'g', label='2020 $O_{3}$')

plt.legend()

plt.xlim(df.loc[0]['DAY'] , df.loc[91]['DAY'])
plt.ylim(0,150)

plt.axvline(x='4-May' ,color='r')
plt.axvline(x='22-Mar' ,color='r')
plt.xticks(rotation=90)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

# Assuming df is your DataFrame

# Calculate Pearson correlation coefficient
r = stats.pearsonr(df['O320'].values[:23], df['NO20'].values[:23])[0]

# Plotting
plt.figure(figsize=(5, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$NO$ $[μg/m^{3}]$')

# Filter zero values
x = df['O320'].values[:23]
y = df['NO220'].values[:23]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask], label='2020')

# Linear regression line
m, b = np.polyfit(x[mask], y[mask], 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 70, 10))
plt.yticks(np.arange(0, 70, 10))
plt.grid(True)

# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %%
r=scipy.stats.pearsonr(df['O320'][0:23],df['NO20'][0:23])[0]

plt.figure(figsize=(5,3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$NO$ $[μg/m^{3}]$')

x=[]
for i in df['O320'][0:23]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['NO20'][0:23]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.scatter(x, y, label='2020')
plt.legend()

m, b = np.polyfit(df['O320'][0:23],df['NO20'][0:23], 1)

plt.ylim(0,50)
xx=np.linspace(5,50,40)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

# Assuming df is your DataFrame

# Calculate Pearson correlation coefficient
r = stats.pearsonr(df['O320'].values[23:66], df['NO20'].values[23:66])[0]

# Plotting
plt.figure(figsize=(5, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$NO$ $[μg/m^{3}]$')

# Filter zero values
x = df['O320'].values[23:66]
y = df['NO220'].values[23:66]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask], label='2020')

# Linear regression line
m, b = np.polyfit(x[mask], y[mask], 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 70, 10))
plt.yticks(np.arange(0, 70, 10))
plt.grid(True)

# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %%
plt.figure(figsize=(5,3))
plt.xlabel('$O_{3}$  $[μg/m^{3}]$')
plt.ylabel('$NO$ $[μg/m^{3}]$')

x=[]
for i in df['O320'][23:66]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['NO20'][23:66]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

r=scipy.stats.pearsonr(x,y)[0]

plt.scatter(x, y, label='2020')
plt.legend()

plt.ylim(0,25)
plt.xticks(np.arange(0,75,5))
m, b = np.polyfit(x, y, 1)

xx=np.linspace(20,70,300)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

# Assuming df is your DataFrame

# Calculate Pearson correlation coefficient
r = stats.pearsonr(df['O320'].values[66:91], df['NO20'].values[66:91])[0]

# Plotting
plt.figure(figsize=(5, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$NO$ $[μg/m^{3}]$')

# Filter zero values
x = df['O320'].values[66:91]
y = df['NO220'].values[66:91]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask], label='2020')

# Linear regression line
m, b = np.polyfit(x[mask], y[mask], 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 70, 10))
plt.yticks(np.arange(0, 70, 10))
plt.grid(True)

# Set equal scaling
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %%
plt.figure(figsize=(5,3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$NO$   $[μg/m^{3}]$')

x=[]
for i in df['O320'][66:91]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['NO20'][66:91]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

r=scipy.stats.pearsonr(x,y)[0]

plt.scatter(x, y, label='2020')
plt.legend()

plt.ylim(0,40)
plt.xticks(np.arange(0,55,5))
r=scipy.stats.pearsonr(x,y)[0]
m, b = np.polyfit(x,y, 1)

xx=np.linspace(2,50,30)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()

# %% [markdown]
# # CO

# %%
fig,ax = plt.subplots(figsize=(13, 2))

x=[]
for i in df['CO20']:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['O320']:
  if i==0:
    y+=[None]
  else:
    y+=[i]

ax.plot(df['DAY'], x, 'g', label='$CO$ 2020')
plt.xticks(rotation=90)

ax2=ax.twinx()
ax2.plot(df['DAY'], y, 'b', label='$O_{3}$ 2020')

plt.xlim(df.loc[0]['DAY'] , df.loc[91]['DAY'])
plt.ylim(0,150)
plt.xticks(rotation=90)

plt.xticks(rotation=90)

plt.axvline(x='4-May' ,color='r')
plt.axvline(x='22-Mar' ,color='r')

ax.set_xlabel('Days')
ax.set_ylabel(r"CO  $[mg/m^{3}$]")
ax2.set_ylabel(r"$O_{3} \: [μg/m^{3}$]")
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

# Assuming df is your DataFrame

# Calculate Pearson correlation coefficient
r = stats.pearsonr(df['O320'].values[0:23], df['CO20'].values[0:23])[0]

# Plotting
plt.figure(figsize=(3, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$CO  \, mg/m^{3}]$')  # Adjusted y-axis label

# Filter zero values
x = df['O320'].values[0:23]
y = df['CO20'].values[0:23]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask]*100, label='2020')

# Linear regression line
m, b = np.polyfit(x[mask], y[mask]*100, 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 110, 10))
plt.yticks(np.arange(0, 110, 10))
plt.grid(True)

plt.gca().set_aspect('auto', adjustable='box')
plt.annotate('$\\times 10^{-2}$', xy=(-0.07, 1), xycoords='axes fraction',
             fontsize=10, ha='right', va='bottom')

plt.show()

# %%
r=scipy.stats.pearsonr(df['O320'][0:23],df['CO20'][0:23])[0]

plt.figure(figsize=(5,3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$CO$ $[mg/m^{3}]$')

x=[]
for i in df['O320'][0:23]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['CO20'][0:23]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

plt.scatter(x, y, label='2020')
plt.legend()

m, b = np.polyfit(df['O320'][0:23],df['CO20'][0:23], 1)

xx=np.linspace(5,50,40)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

# Assuming df is your DataFrame

# Calculate Pearson correlation coefficient
r = stats.pearsonr(df['O320'].values[23:66], df['CO20'].values[23:66])[0]

# Plotting
plt.figure(figsize=(3, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$CO  \, mg/m^{3}]$')  # Adjusted y-axis label

# Filter zero values
x = df['O320'].values[23:66]
y = df['CO20'].values[23:66]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask]*100, label='2020')

# Linear regression line
m, b = np.polyfit(x[mask], y[mask]*100, 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 110, 10))
plt.yticks(np.arange(0, 110, 10))
plt.grid(True)

plt.gca().set_aspect('auto', adjustable='box')
plt.annotate('$\\times 10^{-2}$', xy=(-0.07, 1), xycoords='axes fraction',
             fontsize=10, ha='right', va='bottom')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import pandas as pd

# Assuming df is your DataFrame

# Calculate Pearson correlation coefficient
r = stats.pearsonr(df['O320'].values[66:91], df['CO20'].values[66:91])[0]

# Plotting
plt.figure(figsize=(3, 3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$CO  \, mg/m^{3}]$')  # Adjusted y-axis label

# Filter zero values
x = df['O320'].values[66:91]
y = df['CO20'].values[66:91]
mask = (x != 0) & (y != 0)

plt.scatter(x[mask], y[mask]*100, label='2020')

# Linear regression line
m, b = np.polyfit(x[mask], y[mask]*100, 1)
plt.plot(x[mask], m*x[mask] + b, label=f'Linear Fit ($r$={r:.3f})', color='red')

plt.legend()
plt.xticks(np.arange(0, 110, 10))
plt.yticks(np.arange(0, 110, 10))
plt.grid(True)

plt.gca().set_aspect('auto', adjustable='box')
plt.annotate('$\\times 10^{-2}$', xy=(-0.07, 1), xycoords='axes fraction',
             fontsize=10, ha='right', va='bottom')

plt.show()

# %%
plt.figure(figsize=(5,3))
plt.xlabel('$O_{3}$ $[μg/m^{3}]$')
plt.ylabel('$CO$   $[mg/m^{3}]$')

x=[]
for i in df['O320'][66:91]:
  if i==0:
    x+=[None]
  else:
    x+=[i]

y=[]
for i in df['CO20'][66:91]:
  if i==0:
    y+=[None]
  else:
    y+=[i]

r=scipy.stats.pearsonr(x,y)[0]

plt.scatter(x, y, label='2020')
plt.legend()

r=scipy.stats.pearsonr(x,y)[0]
m, b = np.polyfit(x,y, 1)

xx=np.linspace(2,50,30)
plt.plot(xx, m*xx + b, label='r=%.3f' %(r))
plt.legend()

plt.show()
